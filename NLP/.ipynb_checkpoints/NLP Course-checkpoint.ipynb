# %%
import re
string = "My mom loves a tiger which is the national animal of INDIA!"
pattern = "Tiger"
result = re.match(pattern,string)
print(result.group(0))
# Out:
# Tiger

# %%
mo = re.search(pattern, string)
print(mo.group(0))
# Out:
# Tiger

# %%
pattern2 = "national"
mo1 = re.sub(pattern,'love',string)
print(mo1)
# Out:
# love is the national animal of INDIA!

# %%
from collections import OrderedDict
import numpy as np
import spacy
import pandas as pd
from spacy.lang.en.stop_words import STOP_WORDS

nlp = spacy.load('en_core_web_sm')

class TextRank4Keyword():
    """Extract keywords from text"""
    
    def __init__(self):
        self.d = 0.85 # damping coefficient, usually is .85
        self.min_diff = 1e-5 # convergence threshold
        self.steps = 10 # iteration steps
        self.node_weight = None # save keywords and its weight

    
    def set_stopwords(self, stopwords):  
        """Set stop words"""
        word_s =[' - ', 'jaenge|', 'haim|', '"', 'hai)|', 'paenge|', '\n', '(', ')' ,'-', 'hai|','?', '!', ',', '|', '.', ';', ':', 'andar', 'ata', 'adi', 'apa', 'apana', 'apani', 'apani', 'apane', 'abhi', 'abhi',  'adi', 'apa', 'inhim', 'inhem', 'inhom', 'itayadi', 'ityadi', 'ina', 'inaka', 'inhim', 'inhem', 'inhom', 'isa', 'isaka', 'isaki', 'isaki', 'isake', 'isamem', 'isi', 'isi', 'ise', 'unhim', 'unhem', 'unhom', 'una', 'unaka', 'unaki', 'unaki', 'unake', 'unako', 'unhim', 'unhem', 'unhom', 'usa', 'usake', 'usi', 'usi', 'use', 'eka', 'evam', 'esa', 'ese', 'aise', 'ora', 'aura', 'kai', 'kai', 'kara', 'karata', 'karate', 'karana', 'karane', 'karem', 'kahate', 'kaha', 'ka', 'kaphi', 'kai', 'ki', 'kinhem', 'kinhom', 'kitana', 'kinhem', 'kinhom', 'kiya', 'kira', 'kisa', 'kisi', 'kisi', 'kise', 'ki', 'kuchha', 'kula', 'ke', 'ko', 'koi', 'koi', 'kona', 'konasa', 'kauna', 'kaunasa', 'gaya', 'ghara', 'jaba', 'jaham', 'jaham', 'ja', 'jinhem', 'jinhom', 'jitana', 'jidhara', 'jina', 'jinhem', 'jinhom', 'jisa', 'jise', 'jidhara', 'jesa', 'jese', 'jaisa', 'jaise', 'jo', 'taka', 'taba', 'taraha', 'tinhem', 'tinhom', 'tina', 'tinhem', 'tinhom', 'tisa', 'tise', 'to', 'tha', 'thi', 'thi', 'the', 'dabara', 'davara', 'diya', 'dusara', 'dusare', 'dusare', 'do', 'dvara', 'na', 'nahim', 'nahim', 'na', 'niche', 'nihayata', 'niche', 'ne', 'para', 'pahale', 'pura', 'pura', 'pe', 'phira', 'bani', 'bani', 'bahi', 'bahi', 'bahuta', 'bada', 'bala', 'bilakula', 'bhi', 'bhitara', 'bhi', 'bhitara', 'magara', 'mano', 'me', 'mem', 'yadi', 'yaha', 'yaham', 'yaham', 'yahi', 'yahi', 'ya', 'yiha', 'ye', 'rakhem', 'ravasa', 'raha', 'rahe', 'vasa', 'lie', 'liye', 'lekina', 'va', 'vageraha', 'varaga', 'varga', 'vaha', 'vaham', 'vaham', 'vahim', 'vahim', 'vale', 'vuha', 've', 'va', 'airaha', 'sanga', 'sakata', 'sakate', 'sabase', 'sabhi', 'sabhi', 'satha', 'sabuta', 'sabha', 'sara', 'se', 'so', 'hi', 'hi', 'hua', 'hua', 'hui', 'hui', 'hue', 'he', 'hem', 'hai', 'haim', 'ho', 'hota', 'hoti', 'hoti', 'hote', 'hona', 'hone', 'sabha', 'sara', 'se', 'so', 'hi', 'hi', 'hua', 'hua', 'hui', 'hui', 'hue', 'he', 'hem', 'hai', 'haim', 'ho', 'hota', 'hoti', 'hoti', 'hote', 'hona', 'hone''sabha', 'sara', 'se', 'so', 'hi', 'hi', 'hua', 'hua', 'hui', 'hui', 'hue', 'he', 'hem', 'hai', 'haim', 'ho', 'hota', 'hoti', 'hoti', 'hote', 'hona', 'hone']

        for word in word_s:
           lexeme = nlp.vocab[word]
           lexeme.is_stop = True 
            
    
    def sentence_segment(self, doc, candidate_pos, lower):
        """Store those words only in cadidate_pos"""
        sentences = []
        for sent in doc.sents:
            selected_words = []
            for token in sent:
                # Store words only with cadidate POS tag
                #if token.pos_ in candidate_pos and token.is_stop is False:
                if token.is_stop is False:
                    if lower is True:
                        selected_words.append(token.text.lower())
                    else:
                        selected_words.append(token.text)
            sentences.append(selected_words)
            
        print(sentences)    
        return sentences
        
    def get_vocab(self, sentences):
        """Get all tokens"""
        vocab = OrderedDict()
        i = 0
        for sentence in sentences:
            for word in sentence:
                if word not in vocab:
                    vocab[word] = i
                    i += 1
        return vocab
    
    def get_token_pairs(self, window_size, sentences):
        """Build token_pairs from windows in sentences"""
        token_pairs = list()
        token_pairs_freq = []
        for sentence in sentences:
            for i, word in enumerate(sentence):
                for j in range(i+1, i+window_size):
                    if j >= len(sentence):
                        break
                    pair = (word, sentence[j])    
                    token_pairs.append(pair)
        for word in token_pairs:
            print(word)
        token_pairs_freq = pd.Series(token_pairs).value_counts()    
        print(token_pairs_freq)
        return token_pairs
        
    def symmetrize(self, a):
        return a + a.T - np.diag(a.diagonal())
    
    def get_matrix(self, vocab, token_pairs):
        """Get normalized matrix"""
        # Build matrix
        vocab_size = len(vocab)
        g = np.zeros((vocab_size, vocab_size), dtype='float')
        for word1, word2 in token_pairs:
            i, j = vocab[word1], vocab[word2]
            g[i][j] = 1
            
        # Get Symmeric matrix
        g = self.symmetrize(g)
        
        # Normalize matrix by column
        norm = np.sum(g, axis=0)
        g_norm = np.divide(g, norm, where=norm!=0) # this is ignore the 0 element in norm
        
        return g_norm

    
    def get_keywords(self, number):
        """Print top number keywords"""
        node_weight = OrderedDict(sorted(self.node_weight.items(), key=lambda t: t[1], reverse=True))
        for i, (key, value) in enumerate(node_weight.items()):
            print(key + ' - ' + str(value))
            if i > number:
                break
        
        
    def analyze(self, text, 
                candidate_pos=['NOUN', 'PROPN'], 
                window_size=4, lower=False, stopwords=list()):
        """Main function to analyze text"""
        
        # Set stop words
        self.set_stopwords(stopwords)
        
        # Pare text by spaCy
        doc = nlp(text)
        
        # Filter sentences
        sentences = self.sentence_segment(doc, candidate_pos, lower) # list of list of words
        
        # Build vocabulary
        vocab = self.get_vocab(sentences)
        
        # Get token_pairs from windows
        token_pairs = self.get_token_pairs(window_size, sentences)
        
        # Get normalized matrix
        g = self.get_matrix(vocab, token_pairs)
        
        # Initionlization for weight(pagerank value)
        pr = np.array([1] * len(vocab))
        
        # Iteration
        previous_pr = 0
        for epoch in range(self.steps):
            pr = (1-self.d) + self.d * np.dot(g, pr)
            if abs(previous_pr - sum(pr))  < self.min_diff:
                break
            else:
                previous_pr = sum(pr)

        # Get weight for each node
        node_weight = dict()
        for word, index in vocab.items():
            node_weight[word] = pr[index]
        
        self.node_weight = node_weight
        
        
        
text = '''trevarsa tainka kabutara, mora aura titara jaisi vibhinna jatiyom ke pakshiyom ke karana pakshi - avalokana ke lie prasiddha hai | guru shikhara maunta abu ki sabase unchi choti hai jaham se pure shahara ka bahuta achchha naja़ara dikhata hai| parvata ke shikhara para sthita eka chhota-sa shaiva punya-sthala aura dattatreya ka mandira bhramana ke do mahatvapurna sthana haim| rajasthana ke thara marusthala ke asali jadu ka anubhava pane ka sabase achchha tarika hai marusthala sapha़ari | maunta abu mem rajasthali, rajasthana shasakiya hastashilpa emporiyama aura khadi bhandara kharidari ke mahatvapurna sthana haim | apraila se juna aura aktubara se navambara ka samaya isa shahara ke bhramana ke lie sabase achchha hai | sahasika karyom ki talasha mem nikale paryatakom ke lie thara marusthala ke andaruni hissom mem ghumane, shaharom aura aitihasika khandaharom ko dekhane ke lie unta sapha़ari sarvottama vikalpa hai | rajasthana ke chhote- chhote gamvom mem ghumane ke anokhe anubhava ke lie unta sapha़ari eka romanchaka aura jokhima -bhara sadhana hai | thara marusthala ke khule bhubhaga para ghumane lie jipa sapha़ari eka adbhuta sadhana hai aura rajasthana ke khubasurata, shanta aura ranga-birange ilake ko dekhane ka anokha avasara pradana karati hai | ananda aura romancha ke mishrana ke satha rajasthana ke thara marusthala mem jipa sapha़ari vaham ke kuchha shanadara gantavyom ko samavishta karati hai| thara marusthala ke bhavya retile tile rajasthana ki anokhi dena haim jo ki vaham ki ranga-birangi sanskriti,vanya - jivana, aitihasika smarakom, kilom, udyanom aura jilom se alaga haim | insani hunara aura acharana se anachhue rajasthana ke ye retile tile prakriti ka eka uttama upahara haim jo registana ka eka jadui naja़ara pesha karate haim | nile asamana ke niche hava se akara mem dhale retile tile duniya -bhara se bada़i sankhya mem paryatakom ko akarshita karate haim aura rajasthana ki koi bhi saira ina retile tilom ki saira ke bina adhuri hai | retile tilom dvara bani laharem photographa़rom ke lie pha़oto khinchane ke lie uttama sthana rachati haim | rajasthana ke marusthala ki saira karane ka sarvottama tarika unta sapha़ari ke madhyama se hai, jo registani paryatana ka sabase lokapriya sadhana hai | rajasthana ke andaruni hisse sirpha़ isi sadhana ke jarie dekhe ja sakate haim jise prayah ‘registana ka jahaja’ kaha jata hai | rajasthana mem unta sapha़ari solahavim shatabdi se prachalana mem hai jise taba mukhya rupa se samana dhone ke lie istemala kiya jata tha, aura aba yaha manoranjana ka mahatvapurna sadhana hai | rajasthana ke thara marusthala mem chalane vale unta sapha़ari ke aja ke rupa mem prachina unta- karavam ka jadu dekha ja sakata hai | rajasthana - bhramana ka eka mahatvapurna hissa, unta sapha़ari paramparika aura ranga-birange rajasthana ki andaruni janki dikhata hai |
jaisalamera, jodhapura aura bikanera retile tilom ke lie jane jate haim para inamem se sabase lokapriya jaisalamera hai | adhikatara reta ke tile jaisalamera ke asapasa haim | saima sainda dyunsa eka uttama paryataka sthana hai jo suryasta evam suryodaya ke darshaniya sthala ke rupa mem jana jata hai | saima sainda dyunsa manava ke lie prakriti ke sarvashreshtha upaharom mem se eka hai | jaisalamera ke thara marusthala kshetra mem sthita saima sainda dyunsa sabase adhika prasiddha reta ke tilom mem se hai jo sala -bhara paryatakom ki bahuta bada़i sankhya ko akarshita karata hai | manavara marusthala bahari sahasika karanamom evam romancha ke lie sarvottama hai | paryataka apane apa ko adivasi gamvom ki yatra, marusthala ke vanya jivana ka darshana aura sthaniya shilpakarom ke shilpa ko dekhane mem vyasta rakha sakate haim | bikanera rajasthana ke uttara mem sthita hai aura samanyataya unta- pradesha ke rupa mem jana jata hai | vishva ki dasa pramukha shanadara relagada़iyom mem se eka, pailesa ऑna hvilsa, bharata ki shana kahi ja sakati hai jo yatra ki apani anupama, atulaniya, avismaraniya evam advitiya shaili ke lie jani jati hai | rajasthana ki rajasi bhumi ke darshana karane ke sarvottama madhyamom mem se eka, pailesa ऑna vhilsa bharata ke preranadayaka, atulaniya, avishvasaniya, prabhavashali evam preranatmaka kshetra se gujarati hai | bharatiya rela evam rajasthana paryataka vikasa nigama ke sanyukta prayasom se bharata ki pahali avakasha - relagada़i, pailesa ऑna vhilsa ne 1982 mem apani rajasi yatra arambha ki thi| aja yaha bhavya pailesa ऑna vhilsa relagada़i rajasi rajasthana ka anivarya hissa aura bharata ka gaurava ho gai hai jo rajasthana ke kuchha sarvottama paryataka - sthalom ke darshana karati hai | yaha rajasi yatra mai se agasta ke bicha ke mahinom ko chhoda़kara varsha - bhara hoti hai | vishva ki sarvottama romanchaka yatraom mem se eka pailesa ऑna vhilsa yatra ke daurana vishva stara ki sevaem evam suvidhaem pradana karati hai yaha rajasi yatra dilli se arambha hoti hai aura jayapura - jaisalamera - jodhapura - savai madhopura- chittauda़gadha़ - udayapura - bharatapura - agara hote hue dilli mem akara samapta hoti hai | pushkara mela pratyeka varsha hindu maha kartika (aktubara - navambara) ki shubha purnima ke avasara para lagata hai | rajasthana - bhavya, prakritika aura vastushilpiya ashcharyom se vibhushita pradesha | alabarta hala sangrahalaya jayapura, rajya ka sabase purana sangrahalaya mana jata hai |
paryatana vibhaga ne paryatana sankula ke nirmana ke lie kai nae sthanom ko nirdeshita kiya hai | hariyana paryatana ne hariyana ke sabhi kshetrom mem hotalom, motalom aura bhojanalayom ka prabandha kiya hai | panipata yamuna nadi ke tata para sthita hai aura yaham panipata ke tina aitihasika yuddha lada़e gae the | panipata eka audyogika shahara hai aura hathakaragha utpadom ke lie jana jata hai | jaham taka pata laga hai ‘danavira karna ka shahara’ karanala, divarom se ghira hua shahara raha hai aura shayada kisi samaya mem eka durga raha hoga| karanala jutom, krishi anusandhana sansthanom aura basamati chavala ke lie prasiddha hai|
panchakula jile mem uposhnakatibandhiya mahadvipiya manasuni jalavayu hai jaham hamem ritu avartana, garama grishmaritu, thandi shitaritu, aniyamita varsha aura tapamana mem atyadhika parivartana milata hai|
paryatana karane ke lie atyanta manorama sthalom mem se kuchha haim, kinnaura jile mem sangala ghati aura kalpa, shimala jile mem naladehara, narakanda aura sarahana, kullu jile mem manali aura manikarana, kangada़a jile mem dharmashala tatha lahaula aura spiti mem tabo | palamapura apane krishi mahavidyalaya aura chaya baganom ke lie prasiddha hai | himachala pradesha vanya-jivana premiyom, pakshi prekshakom tatha sahasika paryatakom ke saira karane ke lie bahuta achchhi jagaha hai | shimala paryatakom mem eka lokapriya shahara hai | shimala ki saira karane ke lie sala ke sarvottama mahine marcha - juna (vasanta), sitambara - aktubara (sharada) aura disambara - janavari (shitakalina himapata ka anubhava lene ke lie) haim | himachchhadita himalaya shrinkhala shimala se dikhai pada़ti hai | rajasthana apane paryatakom ke lie vividha prakara ke bhojana prastuta karata hai- yaha vividhata isaki sanskriti, isaki paitrika sanrachana, isaki bhaugolika sthiti aura isaki jalavayu jaisi vividha hai | da raॉyala kairija़ma ऑpha rajasthana tura (rajasi akarshana ki rajasthana yatra) ise sansara ke ati vanchhita paryataka gantavya karara deta hai | bharata ki prakritika sampada usaki sanskritika sampada ki taraha sanriddha aura vividha hai | yaham ke vanya-jiva abhayaranya aura rashtriya udyana apako vahi sara dete haim | raॉyala bangala taigara isa sanriddha kshetra mem basa hai, (jo) raॉyala taigara kaita ka ekamatra nivasa-sthana (hai)| bangala taigara sabase teja़ dauda़ne vala janavara hai | agara apa raॉyala bangala taigara mem dilachaspi rakhate haim tatha use usake svabhavika parivesha mem dekhana chahate haim, (to) ina bagha rakshita sthanom ki yatra avashya anandadayaka hogi | karbeta ka karbeta neshanala parka baghom aura satha hi unake shikara ke lie bhi ekaashraya-sthala hai, jinamem chara prakara ke hirana, jangali suara aura kuchha kama prasiddha janavara sammilita haim | svarna mandira sikkhom ke pavitra nagara anritasara mem sthita hai, jo kabhi ghana jangala tha aura gurunanaka ka nivasa-sthala tha | maidanom ke upara sthita dharmashala ghane chida़ ke peda़om aura devadara ke jangalom se ghiri hai| bahuta si jala dharaom ke satha pasa ki hima-rekha aura shitala svastha vatavarana parivesha ko bahuta hi lubhavana banata hai| kabhi shasana ka eka mahatvapurna kendra mana jane vala chanda vansha ka rajadhani shahara kangada़a, gaurava ki eka gatha kahata hai, jo itihasa mem kho gaya hai| ninna himalaya ki manorama ghatiyom mem se eka, utkrishta dhauladhara pahadiyom dvara parirakshita yaha ghati hari-bhari aura sanriddha hai | sikkima ke parvatiya kshetra mem hare-bhare pahada़i rastom, stupom, mathom aura mandirom ke satha-satha romancha ki prachurata hai | sanriddha sanskriti aura parampara ka parichaya prapta kijie jo ki apane asimita anandaprada sanskarom evam utsavom ke karana purnatah vilakshana evam mohaka hai | sikkima eka sukhadayi yatra pradana karata hai – romancha aura khoja ka eka paryatana | bahuta lambe samaya se manava apane hridaya mem eka chida़iya ki bhanti vishala nile akasha mem uda़ne ki gahari chaha lie hue hai, kuchha hada taka hama manava khule akasha mem uda़ne ke lie havai - khela ke romancha ko apanate hue apani isa pyasa ko buja pane mem sakshama haim | 26,000 phuta ki unchai para barpha se dhaki chotiyom ke shikhara vala himalaya vishva ki sarvashreshtha parvata shrrinkhala hai|
bharata mem paidala - yatra eka avismaraniya anubhava hai kyom ki yaha apako prakriti dvara nirmita ajnata rastom ka anubhava hi nahim deti,(balki) paidala - yatra paryataka ko desha aura isake logom ke satha sidhe samparka mem lati hai aura apako parvatiya vatavarana ko samajane mem sahayata karati hai | himalaya vishva ki sabase taruna parvata shrrinkhalaom mem se eka hai aura vishva ke sarvashreshtha parvatarohana kshetrom mem se gina jata hai| bharatiya himalaya shrrinkhala nissandeha vishva ki sabase bhavya aura prabhavashali parvata shrrinkhalaom mem se eka hai| thara registana mem sahasika yatra aisi yatra hai jise apa apane pure jivana mem nahim bhula paenge| paryataka usi registani anubhava ka ananda jaisalamera, rajasthana mem saima sainda dyunsa mem bhi le sakate haim jaham paryatakom ke manoranjana ke lie rajasthana paryatana vibhaga dvara sayankala mem sanskritika pradarshanom ka ayojana kiya jata hai. gira rashtriya udyana sagauna, gulamohara, khaira aura baragada vrikshom ka eka mila-jula patajada़i vana hai| satha hi gira rashtriya udyana bharata ke kisi bhi udyana ki tulana mem chite ki sabase adhika abadi vala avasa hai| bharata mem bahuta se bagha arakshita kshetra haim, jo isa khunkhara janavara ko surakshita rakha rahe haim, lekina jitani bahutayata aura niyamitata se inhem kanha rashtriya udyana mem dekha ja sakata hai vaisa aura kahim nahim | vishva ke sarvottama pakshi udyanom mem se eka, bharatapura pakshi abhayavana (kevaladeva ghana neshanala parka) eka arakshita kshetra hai jo pashu-varga ko bhi sanrakshana deta hai| udyana dekhane vale adhikansha paryatakom ka mukhya akarshana bahuta se pravasi pakshi hote haim jo saiberiya aura madhya eshiya jaise sudura pradeshom se ate haim aura apane prajanana sthanom ko lautane se pahale ve apani thanda bharatapura mem bitate haim | bharatapura abhayavana ke bada bharatapura shasakiya sangrahalaya mukhya dhyana khinchane valom mem se eka hai, jo bharatapura ke bhutakalina rajasi vaibhava ki jalaki pradana karata hai | sariska udyana tendue, jangali kutte, vana billi, lakada़bagghe, bheda़iye aura bagha ke satha-satha bahuta se mansahari pashuom ka ghara hai| sariska risasa bandarom ki adhika janasankhya ke lie suprasiddha hai, jo ki talavriksha ke asa-pasa adhika sankhya mem paye jate hai|
ranathambhaura rashtriya udyana projekta taigara rija़rvsa ऑpha da varlda (vishva ki bagha sanrakshana pariyojana) ke antargata sammilita hai aura apani bagha janasankhya ke lie adhika lokapriya hai| bagha ko usake prakritika avasa mem dekhana pratyeka vanyajivana samarthaka ki sabase vanchhaniya kalpana hai, jo ki ranathambhaura ke vana mem purna ho sakati hai| ranathambhaura vanyajivana udyana vishva ke kuchha una darshaniya sthanom mem se hai jaham baghom ka varchasva hai| ranathambhaura vanyajivana udyana daladali magaramachchha aura ubhayachara pashuom ke satha-satha chida़iyom ki 272 jatiyom aura sarisripom ka eka avasa hai| ranathambhaura vana ke chhupe hue khajane ki khoja ke lie jipa yatra bhi upalabdha karata hai, kyonki yaha raॉyala taigara ki khoja ke lie sarvottama sadhana hai| vanyajivana rashtriya udyana mem anya akarshana ranathambhaura kile ke khandahara aura jogi mahala hai jo ki 10vim shatabdi ko dinankita karate hai| aba vana vishrama griha mem parivartita jogi mahala bharata mem dusare sabase bada़e baragada ke vriksha ke lie prasiddha hai| taja nissandeha vishva ke sabase bhavya bhavanom mem se eka hai| apani sthapatya bhavyata aura kalatmaka sundarata ke lie prasiddha taja manava ki sabase gauravashali rachanaom mem gina jata hai aura vishva ke shreshtha ashcharyom ki suchi mem nirapavada rupa se sammilita hai| bharatiya pratishthita kavi taigora dvara " shashvatata ke chehare para ansu" ke rupa mem varnita, tajamahala nissandeha mugala vastukala ki parakashtha hai aura nitanta saralata se vishva ke ati ashcharyajanaka bhavanom mem se eka hai| agara apani sthapatya bhavyata ki sanriddhi, baja़arom aura abhushanom ke satha vishva ke ati utkrishta shaharom mem se hai| taja mahotsava ke samaya shilpagrama shahara mem pure vishva ke paryataka ekatra hote haim aura isaka bharapura ananda lete haim| agara ane vale paryataka taja ko apani yadom mem banae rakhane ke lie apane satha isaka eka namuna avashya lem jaenge| agara mem chamada़e ke thailom, kasidakari vale jutom ki kharidadari ka bhi bada़a akarshana hai aura petha (mithai) to nishchita rupa se agara ki eka visheshata hai| yadyapi sudura mem sthita hai, phira bhi khajuraho mandira sankula sthala videshi aura bharatiya donom paryatakom ke lie sarvadhika lokapriya sthanom mem se eka hai| khajuraho ke mandira apani murti kala ke satha paryataka ka dhyana banae rakhate haim, jo ki bahuta utkarsha aura jatila hai, jise aba koi bhi hubahu banane ka sapana bhi nahim dekha sakata| nishpadana mem shreshtha aura bhavabhivyakti mem utkrishta khajuraho mandira naritva ko samarpana haim| kalakara ki srijanatmaka pravrittiyom ne jivana ke vibhinna pahaluom aura bhavom ko patthara mem sundarata se utara hai|'''
tr4w = TextRank4Keyword()
tr4w.analyze(text, candidate_pos = ['NOUN', 'PROPN'], window_size=4, lower=False)
tr4w.get_keywords(25)
# Out:
# [['trevarsa', 'tainka', 'kabutara', 'mora', 'titara', 'jaisi', 'vibhinna', 'jatiyom', 'pakshiyom'], [], ['pakshi', 'avalokana', 'prasiddha'], ['guru', 'shikhara', 'maunta'], ['abu'], [], ['unchi', 'choti', 'pure', 'shahara'], ['achchha', 'naja़ara', 'dikhata', 'parvata'], ['shikhara', 'sthita'], ['chhota', 'sa', 'shaiva', 'punya', 'sthala'], ['dattatreya'], ['mandira', 'bhramana'], ['mahatvapurna', 'sthana', 'rajasthana'], ['thara', 'marusthala', 'asali', 'jadu', 'anubhava', 'pane', 'achchha', 'tarika', 'marusthala', 'sapha़ari', 'maunta'], ['abu', 'rajasthali'], ['rajasthana', 'shasakiya', 'hastashilpa', 'emporiyama', 'khadi', 'bhandara', 'kharidari'], ['mahatvapurna', 'sthana'], [], ['apraila'], ['juna', 'aktubara'], ['navambara', 'samaya', 'shahara'], ['bhramana'], ['achchha'], ['sahasika', 'karyom'], ['talasha', 'nikale', 'paryatakom', 'thara', 'marusthala', 'andaruni', 'hissom', 'ghumane', 'shaharom', 'aitihasika', 'khandaharom'], ['dekhane'], ['unta', 'sapha़ari', 'sarvottama', 'vikalpa'], ['rajasthana'], ['chhote-'], ['chhote', 'gamvom'], ['ghumane', 'anokhe', 'anubhava', 'unta'], ['sapha़ari', 'romanchaka', 'jokhima', '-bhara'], ['sadhana'], ['thara', 'marusthala'], ['khule', 'bhubhaga', 'ghumane', 'jipa', 'sapha़ari', 'adbhuta', 'sadhana'], ['rajasthana', 'khubasurata', 'shanta', 'ranga', 'birange', 'ilake'], ['dekhane'], ['anokha', 'avasara', 'pradana', 'karati', 'ananda', 'romancha', 'mishrana'], ['rajasthana'], ['thara', 'marusthala', 'jipa', 'sapha़ari'], ['shanadara'], ['gantavyom'], ['samavishta', 'karati', 'thara', 'marusthala', 'bhavya', 'retile', 'tile', 'rajasthana'], ['anokhi', 'dena', 'ranga', 'birangi', 'sanskriti', 'vanya', 'jivana', 'aitihasika', 'smarakom', 'kilom', 'udyanom', 'jilom'], ['alaga'], ['insani', 'hunara', 'acharana'], ['anachhue', 'rajasthana'], [], ['retile', 'tile', 'prakriti'], [], ['uttama', 'upahara'], ['registana'], ['jadui', 'naja़ara', 'pesha', 'nile', 'asamana', 'hava'], ['akara', 'dhale', 'retile', 'tile', 'duniya', '-bhara'], ['bada़i', 'sankhya', 'paryatakom'], ['akarshita', 'rajasthana'], ['saira'], ['retile', 'tilom'], ['saira', 'bina'], ['adhuri'], ['retile', 'tilom', 'laharem'], ['photographa़rom'], [], ['pha़oto', 'khinchane'], ['uttama'], ['sthana', 'rachati', 'rajasthana'], ['marusthala'], ['saira'], ['sarvottama', 'tarika', 'unta', 'sapha़ari', 'madhyama'], [], ['registani', 'paryatana', 'lokapriya'], ['sadhana'], ['rajasthana'], ['andaruni', 'hisse'], ['sirpha़', 'sadhana'], ['jarie', 'dekhe'], ['prayah'], ['‘', 'registana', 'jahaja', '’', 'jata'], ['rajasthana', 'unta', 'sapha़ari', 'solahavim', 'shatabdi'], ['prachalana', 'mukhya', 'rupa'], ['samana', 'dhone', 'istemala', 'jata'], ['aba', 'manoranjana', 'mahatvapurna', 'sadhana', 'rajasthana'], ['thara', 'marusthala'], ['chalane', 'unta', 'sapha़ari', 'aja'], ['rupa', 'prachina'], ['unta-', 'karavam'], [], ['jadu', 'dekha'], [], [], [], ['rajasthana', 'bhramana', 'mahatvapurna', 'hissa', 'unta', 'sapha़ari', 'paramparika', 'ranga', 'birange', 'rajasthana'], [], ['andaruni', 'janki', 'dikhata'], ['jaisalamera'], ['jodhapura', 'bikanera', 'retile', 'tilom', 'jane', 'jate', 'inamem', 'lokapriya'], ['jaisalamera'], ['adhikatara', 'reta'], ['tile', 'jaisalamera'], ['asapasa', 'saima', 'sainda', 'dyunsa', 'uttama', 'paryataka', 'sthana'], ['suryasta', 'suryodaya'], ['darshaniya', 'sthala', 'rupa', 'jana', 'jata'], ['saima', 'sainda', 'dyunsa', 'manava'], ['prakriti', 'sarvashreshtha', 'upaharom'], [], ['jaisalamera'], ['thara', 'marusthala', 'kshetra', 'sthita', 'saima', 'sainda', 'dyunsa', 'adhika', 'prasiddha', 'reta'], ['tilom'], ['sala', '-bhara'], ['paryatakom', 'bada़i', 'sankhya'], ['akarshita'], [], ['manavara', 'marusthala', 'bahari', 'sahasika', 'karanamom', 'romancha', 'sarvottama', 'paryataka', 'adivasi', 'gamvom'], ['yatra'], ['marusthala', 'vanya', 'jivana', 'darshana', 'sthaniya', 'shilpakarom', 'shilpa'], ['dekhane', 'vyasta', 'rakha'], ['bikanera', 'rajasthana', 'uttara', 'sthita', 'samanyataya', 'unta-',  ...
# ('trevarsa', 'tainka')
# ('trevarsa', 'kabutara')
# ('trevarsa', 'mora')
# ('tainka', 'kabutara')
# ('tainka', 'mora')
# ('tainka', 'titara')
# ('kabutara', 'mora')
# ('kabutara', 'titara')
# ('kabutara', 'jaisi')
# ('mora', 'titara')
# ('mora', 'jaisi')
# ('mora', 'vibhinna')
# ('titara', 'jaisi')
# ('titara', 'vibhinna')
# ('titara', 'jatiyom')
# ('jaisi', 'vibhinna')
# ('jaisi', 'jatiyom')
# ('jaisi', 'pakshiyom')
# ('vibhinna', 'jatiyom')
# ('vibhinna', 'pakshiyom')
# ('jatiyom', 'pakshiyom')
# ('pakshi', 'avalokana')
# ('pakshi', 'prasiddha')
# ('avalokana', 'prasiddha')
# ('guru', 'shikhara')
# ('guru', 'maunta')
# ('shikhara', 'maunta')
# ('unchi', 'choti')
# ('unchi', 'pure')
# ('unchi', 'shahara')
# ('choti', 'pure')
# ('choti', 'shahara')
# ('pure', 'shahara')
# ('achchha', 'naja़ara')
# ('achchha', 'dikhata')
# ('achchha', 'parvata')
# ('naja़ara', 'dikhata')
# ('naja़ara', 'parvata')
# ('dikhata', 'parvata')
# ('shikhara', 'sthita')
# ('chhota', 'sa')
# ('chhota', 'shaiva')
# ('chhota', 'punya')
# ('sa', 'shaiva')
# ('sa', 'punya')
# ('sa', 'sthala')
# ('shaiva', 'punya')
# ('shaiva', 'sthala')
# ('punya', 'sthala')
# ('mandira', 'bhramana')
# ('mahatvapurna', 'sthana')
# ('mahatvapurna', 'rajasthana')
# ('sthana', 'rajasthana')
# ('thara', 'marusthala')
# ('thara', 'asali')
# ('thara', 'jadu')
# ('marusthala', 'asali')
# ('marusthala', 'jadu')
# ('marusthala', 'anubhava')
# ('asali', 'jadu')
# ('asali', 'anubhava')
# ('asali', 'pane')
# ('jadu', 'anubhava')
# ('jadu', 'pane')
# ('jadu', 'achchha')
# ('anubhava', 'pane')
# ('anubhava', 'achchha')
# ('anubhava', 'tarika')
# ('pane', 'achchha')
# ('pane', 'tarika')
# ('pane', 'marusthala')
# ('achchha', 'tarika')
# ('achchha', 'marusthala')
# ('achchha', 'sapha़ari')
# ('tarika', 'marusthala')
# ('tarika', 'sapha़ari')
# ('tarika', 'maunta')
# ('marusthala', 'sapha़ari')
# ('marusthala', 'maunta')
# ('sapha़ari', 'maunta')
# ('abu', 'rajasthali')
# ('rajasthana', 'shasakiya')
# ('rajasthana', 'hastashilpa')
# ('rajasthana', 'emporiyama')
# ('shasakiya', 'hastashilpa')
# ('shasakiya', 'emporiyama')
# ('shasakiya', 'khadi')
# ('hastashilpa', 'emporiyama')
# ('hastashilpa', 'khadi')
# ('hastashilpa', 'bhandara')
# ('emporiyama', 'khadi')
# ('emporiyama', 'bhandara')
# ('emporiyama', 'kharidari')
# ('khadi', 'bhandara')
# ('khadi', 'kharidari')
# ('bhandara', 'kharidari')
# ('mahatvapurna', 'sthana')
# ('juna', 'aktubara')
# ('navambara', 'samaya')
# ('navambara', 'shahara')
# ('samaya', 'shahara')
# ('sahasika', 'karyom')
# ('talasha', 'nikale')
# ('talasha', 'paryatakom')
# ('talasha', 'thara')
# ('nikale', 'paryatakom')
# ('nikale', 'thara')
# ('nikale', 'marusthala')
# ('paryatakom', 'thara')
# ('paryatakom', 'marusthala')
# ('paryatakom', 'andaruni')
# ('thara', 'marusthala')
# ('thara', 'andaruni')
# ('thara', 'hissom')
# ('marusthala', 'andaruni')
# ('marusthala', 'hissom')
# ('marusthala', 'ghumane')
# ('andaruni', 'hissom')
# ('andaruni', 'ghumane')
# ('andaruni', 'shaharom')
# ('hissom', 'ghumane')
# ('hissom', 'shaharom')
# ('hissom', 'aitihasika')
# ('ghumane', 'shaharom')
# ('ghumane', 'aitihasika')
# ('ghumane', 'khandaharom')
# ('shaharom', 'aitihasika')
# ('shaharom', 'khandaharom')
# ('aitihasika', 'khandaharom')
# ('unta', 'sapha़ari')
# ('unta', 'sarvottama')
# ('unta', 'vikalpa')
# ('sapha़ari', 'sarvottama')
# ('sapha़ari', 'vikalpa')
# ('sarvottama', 'vikalpa')
# ('chhote', 'gamvom')
# ('ghumane', 'anokhe')
# ('ghumane', 'anubhava')
# ('ghumane', 'unta')
# ('anokhe', 'anubhava')
# ('anokhe', 'unta')
# ('anubhava', 'unta')
# ('sapha़ari', 'romanchaka')
# ('sapha़ari', 'jokhima')
# ('sapha़ari', '-bhara')
# ('romanchaka', 'jokhima')
# ('romanchaka', '-bhara')
# ('jokhima', '-bhara')
# ('thara', 'marusthala')
# ('khule', 'bhubhaga')
# ('khule', 'ghumane')
# ('khule', 'jipa')
# ('bhubhaga', 'ghumane')
# ('bhubhaga', 'jipa')
# ('bhubhaga', 'sapha़ari')
# ('ghumane', 'jipa')
# ('ghumane', 'sapha़ari')
# ('ghumane', 'adbhuta')
# ('jipa', 'sapha़ari')
# ('jipa', 'adbhuta')
# ('jipa', 'sadhana')
# ('sapha़ari', 'adbhuta')
# ('sapha़ari', 'sadhana')
# ('adbhuta', 'sadhana')
# ('rajasthana', 'khubasurata')
# ('rajasthana', 'shanta')
# ('rajasthana', 'ranga')
# ('khubasurata', 'shanta')
# ('khubasurata', 'ranga')
# ('khubasurata', 'birange')
# ('shanta', 'ranga')
# ('shanta', 'birange')
# ('shanta', 'ilake')
# ('ranga', 'birange')
# ('ranga', 'ilake')
# ('birange', 'ilake')
# ('anokha', 'avasara')
# ('anokha', 'pradana')
# ('anokha', 'karati')
# ('avasara', 'pradana')
# ('avasara', 'karati')
# ('avasara', 'ananda')
# ('pradana', 'karati')
# ('pradana', 'ananda')
# ('pradana', 'romancha')
# ('karati', 'ananda')
# ('karati', 'romancha')
# ('karati', 'mishrana')
# ('ananda', 'romancha')
# ('ananda', 'mishrana')
# ('romancha', 'mishrana')
# ('thara', 'marusthala')
# ('thara', 'jipa')
# ('thara', 'sapha़ari')
# ('marusthala', 'jipa')
# ('marusthala', 'sapha़ari')
# ('jipa', 'sapha़ari')
# ('samavishta', 'karati')
# ('samavishta', 'thara')
# ('samavishta', 'marusthala')
# ('karati', 'thara')
# ('karati', 'marusthala')
# ('karati', 'bhavya')
# ('thara', 'marusthala')
# ('thara', 'bhavya')
# ('thara', 'retile')
# ('marusthala', 'bhavya')
# ('marusthala', 'retile')
# ('marusthala', 'tile')
# ('bhavya', 'retile')
# ('bhavya', 'tile')
# ('bhavya', 'rajasthana')
# ('retile', 'tile')
# ('retile', 'rajasthana')
# ('tile', 'rajasthana')
# ('anokhi', 'dena')
# ('anokhi', 'ranga')
# ('anokhi', 'birangi')
# ('dena', 'ranga')
# ('dena', 'birangi')
# ('dena', 'sanskriti')
# ('ranga', 'birangi')
# ('ranga', 'sanskriti')
# ('ranga', 'vanya')
# ('birangi', 'sanskriti')
# ('birangi', 'vanya')
# ('birangi', 'jivana')
# ('sanskriti', 'vanya')
# ('sanskriti', 'jivana')
# ('sanskriti', 'aitihasika')
# ('vanya', 'jivana')
# ('vanya', 'aitihasika')
# ('vanya', 'smarakom')
# ('jivana', 'aitihasika')
# ('jivana', 'smarakom')
# ('jivana', 'kilom')
# ('aitihasika', 'smarakom')
# ('aitihasika', 'kilom')
# ('aitihasika', 'udyanom')
# ('smarakom', 'kilom')
# ('smarakom', 'udyanom')
# ('smarakom', 'jilom')
# ('kilom', 'udyanom')
# ('kilom', 'jilom')
# ('udyanom', 'jilom')
# ('insani', 'hunara')
# ('insani', 'acharana')
# ('hunara', 'acharana')
# ('anachhue', 'rajasthana')
# ('retile', 'tile')
# ('retile', 'prakriti')
# ('tile', 'prakriti')
# ('uttama', 'upahara')
# ('jadui', 'naja़ara')
# ('jadui', 'pesha')
# ('jadui', 'nile')
# ('naja़ara', 'pesha')
# ('naja़ara', 'nile')
# ('naja़ara', 'asamana')
# ('pesha', 'nile')
# ('pesha', 'asamana')
# ('pesha', 'hava')
# ('nile', 'asamana')
# ('nile', 'hava')
# ('asamana', 'hava')
# ('akara', 'dhale')
# ('akara', 'retile')
# ('akara', 'tile')
# ('dhale', 'retile')
# ('dhale', 'tile')
# ('dhale', 'duniya')
# ('retile', 'tile')
# ('retile', 'duniya')
# ('retile', '-bhara')
# ('tile', 'duniya')
# ('tile', '-bhara')
# ('duniya', '-bhara')
# ('bada़i', 'sankhya')
# ('bada़i', 'paryatakom')
# ('sankhya', 'paryatakom')
# ('akarshita', 'rajasthana')
# ('retile', 'tilom')
# ('saira', 'bina')
# ('retile', 'tilom')
# ('retile', 'laharem')
# ('tilom', 'laharem')
# ('pha़oto', 'khinchane')
# ('sthana', 'rachati')
# ('sthana', 'rajasthana')
# ('rachati', 'rajasthana')
# ('sarvottama', 'tarika')
# ('sarvottama', 'unta')
# ('sarvottama', 'sapha़ari')
# ('tarika', 'unta')
# ('tarika', 'sapha़ari')
# ('tarika', 'madhyama')
# ('unta', 'sapha़ari')
# ('unta', 'madhyama')
# ('sapha़ari', 'madhyama')
# ('registani', 'paryatana')
# ('registani', 'lokapriya')
# ('paryatana', 'lokapriya')
# ('andaruni', 'hisse')
# ('sirpha़', 'sadhana')
# ('jarie', 'dekhe')
# ('‘', 'registana')
# ('‘', 'jahaja')
# ('‘', '’')
# ('registana', 'jahaja')
# ('registana', '’')
# ('registana', 'jata')
# ('jahaja', '’')
# ('jahaja', 'jata')
# ('’', 'jata')
# ('rajasthana', 'unta')
# ('rajasthana', 'sapha़ari')
# ('rajasthana', 'solahavim')
# ('unta', 'sapha़ari')
# ('unta', 'solahavim')
# ('unta', 'shatabdi')
# ('sapha़ari', 'solahavim')
# ('sapha़ari', 'shatabdi')
# ('solahavim', 'shatabdi')
# ('prachalana', 'mukhya')
# ('prachalana', 'rupa')
# ('mukhya', 'rupa')
# ('samana', 'dhone')
# ('samana', 'istemala')
# ('samana', 'jata')
# ('dhone', 'istemala')
# ('dhone', 'jata')
# ('istemala', 'jata')
# ('aba', 'manoranjana')
# ('aba', 'mahatvapurna')
# ('aba', 'sadhana')
# ('manoranjana', 'mahatvapurna')
# ('manoranjana', 'sadhana')
# ('manoranjana', 'rajasthana')
# ('mahatvapurna', 'sadhana')
# ('mahatvapurna', 'rajasthana')
# ('sadhana', 'rajasthana')
# ('thara', 'marusthala')
# ('chalane', 'unta')
# ('chalane', 'sapha़ari')
# ('chalane', 'aja')
# ('unta', 'sapha़ari')
# ('unta', 'aja')
# ('sapha़ari', 'aja')
# ('rupa', 'prachina')
# ('unta-', 'karavam')
# ('jadu', 'dekha')
# ('rajasthana', 'bhramana')
# ('rajasthana', 'mahatvapurna')
# ('rajasthana', 'hissa')
# ('bhramana', 'mahatvapurna')
# ('bhramana', 'hissa')
# ('bhramana', 'unta')
# ('mahatvapurna', 'hissa')
# ('mahatvapurna', 'unta')
# ('mahatvapurna', 'sapha़ari')
# ('hissa', 'unta')
# ('hissa', 'sapha़ari')
# ('hissa', 'paramparika')
# ('unta', 'sapha़ari')
# ('unta', 'paramparika')
# ('unta', 'ranga')
# ('sapha़ari', 'paramparika')
# ('sapha़ari', 'ranga')
# ('sapha़ari', 'birange')
# ('paramparika', 'ranga')
# ('paramparika', 'birange')
# ('paramparika', 'rajasthana')
# ('ranga', 'birange')
# ('ranga', 'rajasthana')
# ('birange', 'rajasthana')
# ('andaruni', 'janki')
# ('andaruni', 'dikhata')
# ('janki', 'dikhata')
# ('jodhapura', 'bikanera')
# ('jodhapura', 'retile')
# ('jodhapura', 'tilom')
# ('bikanera', 'retile')
# ('bikanera', 'tilom')
# ('bikanera', 'jane')
# ('retile', 'tilom')
# ('retile', 'jane')
# ('retile', 'jate')
# ('tilom', 'jane')
# ('tilom', 'jate')
# ('tilom', 'inamem')
# ('jane', 'jate')
# ('jane', 'inamem')
# ('jane', 'lokapriya')
# ('jate', 'inamem')
# ('jate', 'lokapriya')
# ('inamem', 'lokapriya')
# ('adhikatara', 'reta')
# ('tile', 'jaisalamera')
# ('asapasa', 'saima')
# ('asapasa', 'sainda')
# ('asapasa', 'dyunsa')
# ('saima', 'sainda')
# ('saima', 'dyunsa')
# ('saima', 'uttama')
# ('sainda', 'dyunsa')
# ('sainda', 'uttama')
# ('sainda', 'paryataka')
# ('dyunsa', 'uttama')
# ('dyunsa', 'paryataka')
# ('dyunsa', 'sthana')
# ('uttama', 'paryataka')
# ('uttama', 'sthana')
# ('paryataka', 'sthana')
# ('suryasta', 'suryodaya')
# ('darshaniya', 'sthala')
# ('darshaniya', 'rupa')
# ('darshaniya', 'jana')
# ('sthala', 'rupa')
# ('sthala', 'jana')
# ('sthala', 'jata')
# ('rupa', 'jana')
# ('rupa', 'jata')
# ('jana', 'jata')
# ('saima', 'sainda')
# ('saima', 'dyunsa')
# ('saima', 'manava')
# ('sainda', 'dyunsa')
# ('sainda', 'manava')
# ('dyunsa', 'manava')
# ('prakriti', 'sarvashreshtha')
# ('prakriti', 'upaharom')
# ('sarvashreshtha', 'upaharom')
# ('thara', 'marusthala')
# ('thara', 'kshetra')
# ('thara', 'sthita')
# ('marusthala', 'kshetra')
# ('marusthala', 'sthita')
# ('marusthala', 'saima')
# ('kshetra', 'sthita')
# ('kshetra', 'saima')
# ('kshetra', 'sainda')
# ('sthita', 'saima')
# ('sthita', 'sainda')
# ('sthita', 'dyunsa')
# ('saima', 'sainda')
# ('saima', 'dyunsa')
# ('saima', 'adhika')
# ('sainda', 'dyunsa')
# ('sainda', 'adhika')
# ('sainda', 'prasiddha')
# ('dyunsa', 'adhika')
# ('dyunsa', 'prasiddha')
# ('dyunsa', 'reta')
# ('adhika', 'prasiddha')
# ('adhika', 'reta')
# ('prasiddha', 'reta')
# ('sala', '-bhara')
# ('paryatakom', 'bada़i')
# ('paryatakom', 'sankhya')
# ('bada़i', 'sankhya')
# ('manavara', 'marusthala')
# ('manavara', 'bahari')
# ('manavara', 'sahasika')
# ('marusthala', 'bahari')
# ('marusthala', 'sahasika')
# ('marusthala', 'karanamom')
# ('bahari', 'sahasika')
# ('bahari', 'karanamom')
# ('bahari', 'romancha')
# ('sahasika', 'karanamom')
# ('sahasika', 'romancha')
# ('sahasika', 'sarvottama')
# ('karanamom', 'romancha')
# ('karanamom', 'sarvottama')
# ('karanamom', 'paryataka')
# ('romancha', 'sarvottama')
# ('romancha', 'paryataka')
# ('romancha', 'adivasi')
# ('sarvottama', 'paryataka')
# ('sarvottama', 'adivasi')
# ('sarvottama', 'gamvom')
# ('paryataka', 'adivasi')
# ('paryataka', 'gamvom')
# ('adivasi', 'gamvom')
# ('marusthala', 'vanya')
# ('marusthala', 'jivana')
# ('marusthala', 'darshana')
# ('vanya', 'jivana')
# ('vanya', 'darshana')
# ('vanya', 'sthaniya')
# ('jivana', 'darshana')
# ('jivana', 'sthaniya')
# ('jivana', 'shilpakarom')
# ('darshana', 'sthaniya')
# ('darshana', 'shilpakarom')
# ('darshana', 'shilpa')
# ('sthaniya', 'shilpakarom')
# ('sthaniya', 'shilpa')
# ('shilpakarom', 'shilpa')
# ('dekhane', 'vyasta')
# ('dekhane', 'rakha')
# ('vyasta', 'rakha')
# ('bikanera', 'rajasthana')
# ('bikanera', 'uttara')
# ('bikanera', 'sthita')
# ('rajasthana', 'uttara')
# ('rajasthana', 'sthita')
# ('rajasthana', 'samanyataya')
# ('uttara', 'sthita')
# ('uttara', 'samanyataya')
# ('uttara', 'unta-')
# ('sthita', 'samanyataya')
# ('sthita', 'unta-')
# ('sthita', 'pradesha')
# ('samanyataya', 'unta-')
# ('samanyataya', 'pradesha')
# ('unta-', 'pradesha')
# ('rupa', 'jana')
# ('rupa', 'jata')
# ('jana', 'jata')
# ('vishva', 'dasa')
# ('vishva', 'pramukha')
# ('vishva', 'shanadara')
# ('dasa', 'pramukha')
# ('dasa', 'shanadara')
# ('pramukha', 'shanadara')
# ('pailesa', 'ऑna')
# ('pailesa', 'hvilsa')
# ('ऑna', 'hvilsa')
# ('bharata', 'shana')
# ('bharata', 'kahi')
# ('shana', 'kahi')
# ('anupama', 'atulaniya')
# ('anupama', 'avismaraniya')
# ('anupama', 'advitiya')
# ('atulaniya', 'avismaraniya')
# ('atulaniya', 'advitiya')
# ('atulaniya', 'shaili')
# ('avismaraniya', 'advitiya')
# ('avismaraniya', 'shaili')
# ('advitiya', 'shaili')
# ('jani', 'jati')
# ('rajasthana', 'rajasi')
# ('rajasthana', 'bhumi')
# ('rajasi', 'bhumi')
# ('sarvottama', 'madhyamom')
# ('sarvottama', 'pailesa')
# ('sarvottama', 'ऑna')
# ('madhyamom', 'pailesa')
# ('madhyamom', 'ऑna')
# ('madhyamom', 'vhilsa')
# ('pailesa', 'ऑna')
# ('pailesa', 'vhilsa')
# ('pailesa', 'bharata')
# ('ऑna', 'vhilsa')
# ('ऑna', 'bharata')
# ('vhilsa', 'bharata')
# ('preranadayaka', 'atulaniya')
# ('preranadayaka', 'avishvasaniya')
# ('preranadayaka', 'prabhavashali')
# ('atulaniya', 'avishvasaniya')
# ('atulaniya', 'prabhavashali')
# ('atulaniya', 'preranatmaka')
# ('avishvasaniya', 'prabhavashali')
# ('avishvasaniya', 'preranatmaka')
# ('avishvasaniya', 'kshetra')
# ('prabhavashali', 'preranatmaka')
# ('prabhavashali', 'kshetra')
# ('prabhavashali', 'gujarati')
# ('preranatmaka', 'kshetra')
# ('preranatmaka', 'gujarati')
# ('kshetra', 'gujarati')
# ('bharatiya', 'rela')
# ('bharatiya', 'rajasthana')
# ('bharatiya', 'paryataka')
# ('rela', 'rajasthana')
# ('rela', 'paryataka')
# ('rela', 'vikasa')
# ('rajasthana', 'paryataka')
# ('rajasthana', 'vikasa')
# ('rajasthana', 'nigama')
# ('paryataka', 'vikasa')
# ('paryataka', 'nigama')
# ('paryataka', 'sanyukta')
# ('vikasa', 'nigama')
# ('vikasa', 'sanyukta')
# ('vikasa', 'prayasom')
# ('nigama', 'sanyukta')
# ('nigama', 'prayasom')
# ('sanyukta', 'prayasom')
# ('pahali', 'avakasha')
# ('pahali', 'relagada़i')
# ('pahali', 'pailesa')
# ('avakasha', 'relagada़i')
# ('avakasha', 'pailesa')
# ('avakasha', 'ऑna')
# ('relagada़i', 'pailesa')
# ('relagada़i', 'ऑna')
# ('relagada़i', 'vhilsa')
# ('pailesa', 'ऑna')
# ('pailesa', 'vhilsa')
# ('pailesa', '1982')
# ('ऑna', 'vhilsa')
# ('ऑna', '1982')
# ('ऑna', 'rajasi')
# ('vhilsa', '1982')
# ('vhilsa', 'rajasi')
# ('vhilsa', 'yatra')
# ('1982', 'rajasi')
# ('1982', 'yatra')
# ('1982', 'arambha')
# ('rajasi', 'yatra')
# ('rajasi', 'arambha')
# ('yatra', 'arambha')
# ('thi|', 'aja')
# ('thi|', 'bhavya')
# ('thi|', 'pailesa')
# ('aja', 'bhavya')
# ('aja', 'pailesa')
# ('aja', 'ऑna')
# ('bhavya', 'pailesa')
# ('bhavya', 'ऑna')
# ('bhavya', 'vhilsa')
# ('pailesa', 'ऑna')
# ('pailesa', 'vhilsa')
# ('pailesa', 'relagada़i')
# ('ऑna', 'vhilsa')
# ('ऑna', 'relagada़i')
# ('ऑna', 'rajasi')
# ('vhilsa', 'relagada़i')
# ('vhilsa', 'rajasi')
# ('vhilsa', 'rajasthana')
# ('relagada़i', 'rajasi')
# ('relagada़i', 'rajasthana')
# ('relagada़i', 'anivarya')
# ('rajasi', 'rajasthana')
# ('rajasi', 'anivarya')
# ('rajasi', 'hissa')
# ('rajasthana', 'anivarya')
# ('rajasthana', 'hissa')
# ('rajasthana', 'bharata')
# ('anivarya', 'hissa')
# ('anivarya', 'bharata')
# ('hissa', 'bharata')
# ('sarvottama', 'paryataka')
# ('sarvottama', 'sthalom')
# ('sarvottama', 'darshana')
# ('paryataka', 'sthalom')
# ('paryataka', 'darshana')
# ('paryataka', 'karati')
# ('sthalom', 'darshana')
# ('sthalom', 'karati')
# ('darshana', 'karati')
# ('rajasi', 'yatra')
# ('rajasi', 'mai')
# ('yatra', 'mai')
# ('agasta', 'bicha')
# ('varsha', 'bhara')
# ('vishva', 'sarvottama')
# ('vishva', 'romanchaka')
# ('vishva', 'yatraom')
# ('sarvottama', 'romanchaka')
# ('sarvottama', 'yatraom')
# ('romanchaka', 'yatraom')
# ('pailesa', 'ऑna')
# ('pailesa', 'vhilsa')
# ('pailesa', 'yatra')
# ('ऑna', 'vhilsa')
# ('ऑna', 'yatra')
# ('vhilsa', 'yatra')
# ('daurana', 'vishva')
# ('daurana', 'stara')
# ('vishva', 'stara')
# ('sevaem', 'suvidhaem')
# ('pradana', 'karati')
# ('pradana', 'rajasi')
# ('pradana', 'yatra')
# ('karati', 'rajasi')
# ('karati', 'yatra')
# ('karati', 'dilli')
# ('rajasi', 'yatra')
# ('rajasi', 'dilli')
# ('yatra', 'dilli')
# ('jayapura', 'jaisalamera')
# ('jayapura', 'jodhapura')
# ('jayapura', 'savai')
# ('jaisalamera', 'jodhapura')
# ('jaisalamera', 'savai')
# ('jaisalamera', 'madhopura-')
# ('jodhapura', 'savai')
# ('jodhapura', 'madhopura-')
# ('jodhapura', 'chittauda़gadha़')
# ('savai', 'madhopura-')
# ('savai', 'chittauda़gadha़')
# ('savai', 'udayapura')
# ('madhopura-', 'chittauda़gadha़')
# ('madhopura-', 'udayapura')
# ('madhopura-', 'bharatapura')
# ('chittauda़gadha़', 'udayapura')
# ('chittauda़gadha़', 'bharatapura')
# ('chittauda़gadha़', 'agara')
# ('udayapura', 'bharatapura')
# ('udayapura', 'agara')
# ('udayapura', 'dilli')
# ('bharatapura', 'agara')
# ('bharatapura', 'dilli')
# ('bharatapura', 'akara')
# ('agara', 'dilli')
# ('agara', 'akara')
# ('agara', 'samapta')
# ('dilli', 'akara')
# ('dilli', 'samapta')
# ('akara', 'samapta')
# ('pushkara', 'mela')
# ('pushkara', 'pratyeka')
# ('pushkara', 'varsha')
# ('mela', 'pratyeka')
# ('mela', 'varsha')
# ('mela', 'hindu')
# ('pratyeka', 'varsha')
# ('pratyeka', 'hindu')
# ('pratyeka', 'maha')
# ('varsha', 'hindu')
# ('varsha', 'maha')
# ('varsha', 'kartika')
# ('hindu', 'maha')
# ('hindu', 'kartika')
# ('hindu', 'aktubara')
# ('maha', 'kartika')
# ('maha', 'aktubara')
# ('maha', 'navambara')
# ('kartika', 'aktubara')
# ('kartika', 'navambara')
# ('aktubara', 'navambara')
# ('shubha', 'purnima')
# ('avasara', 'lagata')
# ('rajasthana', 'bhavya')
# ('rajasthana', 'prakritika')
# ('rajasthana', 'vastushilpiya')
# ('bhavya', 'prakritika')
# ('bhavya', 'vastushilpiya')
# ('prakritika', 'vastushilpiya')
# ('ashcharyom', 'vibhushita')
# ('ashcharyom', 'pradesha')
# ('vibhushita', 'pradesha')
# ('alabarta', 'hala')
# ('alabarta', 'sangrahalaya')
# ('alabarta', 'jayapura')
# ('hala', 'sangrahalaya')
# ('hala', 'jayapura')
# ('sangrahalaya', 'jayapura')
# ('purana', 'sangrahalaya')
# ('purana', 'mana')
# ('purana', 'jata')
# ('sangrahalaya', 'mana')
# ('sangrahalaya', 'jata')
# ('mana', 'jata')
# ('paryatana', 'vibhaga')
# ('paryatana', 'sankula')
# ('nae', 'sthanom')
# ('nae', 'nirdeshita')
# ('sthanom', 'nirdeshita')
# ('hariyana', 'paryatana')
# ('hariyana', 'hariyana')
# ('paryatana', 'hariyana')
# ('kshetrom', 'hotalom')
# ('kshetrom', 'motalom')
# ('kshetrom', 'bhojanalayom')
# ('hotalom', 'motalom')
# ('hotalom', 'bhojanalayom')
# ('motalom', 'bhojanalayom')
# ('panipata', 'yamuna')
# ('panipata', 'nadi')
# ('yamuna', 'nadi')
# ('tata', 'sthita')
# ('aitihasika', 'yuddha')
# ('aitihasika', 'lada़e')
# ('aitihasika', 'gae')
# ('yuddha', 'lada़e')
# ('yuddha', 'gae')
# ('yuddha', 'panipata')
# ('lada़e', 'gae')
# ('lada़e', 'panipata')
# ('lada़e', 'audyogika')
# ('gae', 'panipata')
# ('gae', 'audyogika')
# ('gae', 'shahara')
# ('panipata', 'audyogika')
# ('panipata', 'shahara')
# ('panipata', 'hathakaragha')
# ('audyogika', 'shahara')
# ('audyogika', 'hathakaragha')
# ('audyogika', 'utpadom')
# ('shahara', 'hathakaragha')
# ('shahara', 'utpadom')
# ('shahara', 'jana')
# ('hathakaragha', 'utpadom')
# ('hathakaragha', 'jana')
# ('hathakaragha', 'jata')
# ('utpadom', 'jana')
# ('utpadom', 'jata')
# ('jana', 'jata')
# ('pata', 'laga')
# ('karna', 'shahara')
# ('karna', '’')
# ('karna', 'karanala')
# ('shahara', '’')
# ('shahara', 'karanala')
# ('shahara', 'divarom')
# ('’', 'karanala')
# ('’', 'divarom')
# ('’', 'ghira')
# ('karanala', 'divarom')
# ('karanala', 'ghira')
# ('karanala', 'shahara')
# ('divarom', 'ghira')
# ('divarom', 'shahara')
# ('ghira', 'shahara')
# ('shayada', 'samaya')
# ('durga', 'hoga|')
# ('durga', 'karanala')
# ('durga', 'jutom')
# ('hoga|', 'karanala')
# ('hoga|', 'jutom')
# ('hoga|', 'krishi')
# ('karanala', 'jutom')
# ('karanala', 'krishi')
# ('karanala', 'anusandhana')
# ('jutom', 'krishi')
# ('jutom', 'anusandhana')
# ('jutom', 'sansthanom')
# ('krishi', 'anusandhana')
# ('krishi', 'sansthanom')
# ('anusandhana', 'sansthanom')
# ('basamati', 'chavala')
# ('prasiddha', 'panchakula')
# ('prasiddha', 'jile')
# ('prasiddha', 'uposhnakatibandhiya')
# ('panchakula', 'jile')
# ('panchakula', 'uposhnakatibandhiya')
# ('panchakula', 'mahadvipiya')
# ('jile', 'uposhnakatibandhiya')
# ('jile', 'mahadvipiya')
# ('uposhnakatibandhiya', 'mahadvipiya')
# ('manasuni', 'jalavayu')
# ('manasuni', 'hamem')
# ('manasuni', 'ritu')
# ('jalavayu', 'hamem')
# ('jalavayu', 'ritu')
# ('jalavayu', 'avartana')
# ('hamem', 'ritu')
# ('hamem', 'avartana')
# ('hamem', 'garama')
# ('ritu', 'avartana')
# ('ritu', 'garama')
# ('ritu', 'grishmaritu')
# ('avartana', 'garama')
# ('avartana', 'grishmaritu')
# ('avartana', 'thandi')
# ('garama', 'grishmaritu')
# ('garama', 'thandi')
# ('garama', 'shitaritu')
# ('grishmaritu', 'thandi')
# ('grishmaritu', 'shitaritu')
# ('grishmaritu', 'aniyamita')
# ('thandi', 'shitaritu')
# ('thandi', 'aniyamita')
# ('thandi', 'varsha')
# ('shitaritu', 'aniyamita')
# ('shitaritu', 'varsha')
# ('shitaritu', 'tapamana')
# ('aniyamita', 'varsha')
# ('aniyamita', 'tapamana')
# ('aniyamita', 'atyadhika')
# ('varsha', 'tapamana')
# ('varsha', 'atyadhika')
# ('varsha', 'parivartana')
# ('tapamana', 'atyadhika')
# ('tapamana', 'parivartana')
# ('tapamana', 'milata')
# ('atyadhika', 'parivartana')
# ('atyadhika', 'milata')
# ('parivartana', 'milata')
# ('paryatana', 'atyanta')
# ('paryatana', 'manorama')
# ('paryatana', 'sthalom')
# ('atyanta', 'manorama')
# ('atyanta', 'sthalom')
# ('atyanta', 'kinnaura')
# ('manorama', 'sthalom')
# ('manorama', 'kinnaura')
# ('manorama', 'jile')
# ('sthalom', 'kinnaura')
# ('sthalom', 'jile')
# ('sthalom', 'sangala')
# ('kinnaura', 'jile')
# ('kinnaura', 'sangala')
# ('kinnaura', 'ghati')
# ('jile', 'sangala')
# ('jile', 'ghati')
# ('jile', 'kalpa')
# ('sangala', 'ghati')
# ('sangala', 'kalpa')
# ('sangala', 'shimala')
# ('ghati', 'kalpa')
# ('ghati', 'shimala')
# ('ghati', 'jile')
# ('kalpa', 'shimala')
# ('kalpa', 'jile')
# ('kalpa', 'naladehara')
# ('shimala', 'jile')
# ('shimala', 'naladehara')
# ('shimala', 'narakanda')
# ('jile', 'naladehara')
# ('jile', 'narakanda')
# ('jile', 'sarahana')
# ('naladehara', 'narakanda')
# ('naladehara', 'sarahana')
# ('naladehara', 'kullu')
# ('narakanda', 'sarahana')
# ('narakanda', 'kullu')
# ('narakanda', 'jile')
# ('sarahana', 'kullu')
# ('sarahana', 'jile')
# ('sarahana', 'manali')
# ('kullu', 'jile')
# ('kullu', 'manali')
# ('kullu', 'manikarana')
# ('jile', 'manali')
# ('jile', 'manikarana')
# ('manali', 'manikarana')
# ('kangada़a', 'jile')
# ('kangada़a', 'dharmashala')
# ('kangada़a', 'tatha')
# ('jile', 'dharmashala')
# ('jile', 'tatha')
# ('jile', 'lahaula')
# ('dharmashala', 'tatha')
# ('dharmashala', 'lahaula')
# ('dharmashala', 'spiti')
# ('tatha', 'lahaula')
# ('tatha', 'spiti')
# ('tatha', 'tabo')
# ('lahaula', 'spiti')
# ('lahaula', 'tabo')
# ('spiti', 'tabo')
# ('palamapura', 'krishi')
# ('palamapura', 'mahavidyalaya')
# ('palamapura', 'chaya')
# ('krishi', 'mahavidyalaya')
# ('krishi', 'chaya')
# ('krishi', 'baganom')
# ('mahavidyalaya', 'chaya')
# ('mahavidyalaya', 'baganom')
# ('chaya', 'baganom')
# ('himachala', 'pradesha')
# ('himachala', 'vanya')
# ('himachala', 'jivana')
# ('pradesha', 'vanya')
# ('pradesha', 'jivana')
# ('pradesha', 'premiyom')
# ('vanya', 'jivana')
# ('vanya', 'premiyom')
# ('vanya', 'pakshi')
# ('jivana', 'premiyom')
# ('jivana', 'pakshi')
# ('jivana', 'prekshakom')
# ('premiyom', 'pakshi')
# ('premiyom', 'prekshakom')
# ('premiyom', 'tatha')
# ('pakshi', 'prekshakom')
# ('pakshi', 'tatha')
# ('pakshi', 'sahasika')
# ('prekshakom', 'tatha')
# ('prekshakom', 'sahasika')
# ('prekshakom', 'paryatakom')
# ('tatha', 'sahasika')
# ('tatha', 'paryatakom')
# ('sahasika', 'paryatakom')
# ('achchhi', 'jagaha')
# ('shimala', 'paryatakom')
# ('shahara', 'shimala')
# ('shahara', 'saira')
# ('shimala', 'saira')
# ('sarvottama', 'mahine')
# ('sarvottama', 'marcha')
# ('sarvottama', 'juna')
# ('mahine', 'marcha')
# ('mahine', 'juna')
# ('mahine', 'vasanta')
# ('marcha', 'juna')
# ('marcha', 'vasanta')
# ('juna', 'vasanta')
# ('sitambara', 'aktubara')
# ('sitambara', 'sharada')
# ('sitambara', 'disambara')
# ('aktubara', 'sharada')
# ('aktubara', 'disambara')
# ('aktubara', 'janavari')
# ('sharada', 'disambara')
# ('sharada', 'janavari')
# ('sharada', 'shitakalina')
# ('disambara', 'janavari')
# ('disambara', 'shitakalina')
# ('disambara', 'himapata')
# ('janavari', 'shitakalina')
# ('janavari', 'himapata')
# ('janavari', 'anubhava')
# ('shitakalina', 'himapata')
# ('shitakalina', 'anubhava')
# ('shitakalina', 'lene')
# ('himapata', 'anubhava')
# ('himapata', 'lene')
# ('himapata', 'himachchhadita')
# ('anubhava', 'lene')
# ('anubhava', 'himachchhadita')
# ('anubhava', 'himalaya')
# ('lene', 'himachchhadita')
# ('lene', 'himalaya')
# ('lene', 'shrinkhala')
# ('himachchhadita', 'himalaya')
# ('himachchhadita', 'shrinkhala')
# ('himachchhadita', 'shimala')
# ('himalaya', 'shrinkhala')
# ('himalaya', 'shimala')
# ('shrinkhala', 'shimala')
# ('pada़ti', 'rajasthana')
# ('pada़ti', 'paryatakom')
# ('pada़ti', 'vividha')
# ('rajasthana', 'paryatakom')
# ('rajasthana', 'vividha')
# ('rajasthana', 'prakara')
# ('paryatakom', 'vividha')
# ('paryatakom', 'prakara')
# ('vividha', 'prakara')
# ('bhojana', 'prastuta')
# ('vividhata', 'sanskriti')
# ('vividhata', 'paitrika')
# ('vividhata', 'sanrachana')
# ('sanskriti', 'paitrika')
# ('sanskriti', 'sanrachana')
# ('sanskriti', 'bhaugolika')
# ('paitrika', 'sanrachana')
# ('paitrika', 'bhaugolika')
# ('paitrika', 'sthiti')
# ('sanrachana', 'bhaugolika')
# ('sanrachana', 'sthiti')
# ('bhaugolika', 'sthiti')
# ('jalavayu', 'jaisi')
# ('jalavayu', 'vividha')
# ('jalavayu', 'da')
# ('jaisi', 'vividha')
# ('jaisi', 'da')
# ('jaisi', 'raॉyala')
# ('vividha', 'da')
# ('vividha', 'raॉyala')
# ('da', 'raॉyala')
# ('ऑpha', 'rajasthana')
# ('tura', 'rajasi')
# ('tura', 'akarshana')
# ('tura', 'rajasthana')
# ('rajasi', 'akarshana')
# ('rajasi', 'rajasthana')
# ('rajasi', 'yatra')
# ('akarshana', 'rajasthana')
# ('akarshana', 'yatra')
# ('akarshana', 'sansara')
# ('rajasthana', 'yatra')
# ('rajasthana', 'sansara')
# ('yatra', 'sansara')
# ('ati', 'vanchhita')
# ('ati', 'paryataka')
# ('ati', 'gantavya')
# ('vanchhita', 'paryataka')
# ('vanchhita', 'gantavya')
# ('vanchhita', 'karara')
# ('paryataka', 'gantavya')
# ('paryataka', 'karara')
# ('paryataka', 'deta')
# ('gantavya', 'karara')
# ('gantavya', 'deta')
# ('karara', 'deta')
# ('prakritika', 'sampada')
# ('prakritika', 'usaki')
# ('prakritika', 'sanskritika')
# ('sampada', 'usaki')
# ('sampada', 'sanskritika')
# ('sampada', 'sampada')
# ('usaki', 'sanskritika')
# ('usaki', 'sampada')
# ('sanskritika', 'sampada')
# ('sanriddha', 'vividha')
# ('vanya', 'jiva')
# ('vanya', 'abhayaranya')
# ('vanya', 'rashtriya')
# ('jiva', 'abhayaranya')
# ('jiva', 'rashtriya')
# ('jiva', 'udyana')
# ('abhayaranya', 'rashtriya')
# ('abhayaranya', 'udyana')
# ('abhayaranya', 'apako')
# ('rashtriya', 'udyana')
# ('rashtriya', 'apako')
# ('rashtriya', 'vahi')
# ('udyana', 'apako')
# ('udyana', 'vahi')
# ('udyana', 'dete')
# ('apako', 'vahi')
# ('apako', 'dete')
# ('vahi', 'dete')
# ('raॉyala', 'bangala')
# ('raॉyala', 'taigara')
# ('raॉyala', 'sanriddha')
# ('bangala', 'taigara')
# ('bangala', 'sanriddha')
# ('bangala', 'kshetra')
# ('taigara', 'sanriddha')
# ('taigara', 'kshetra')
# ('taigara', 'basa')
# ('sanriddha', 'kshetra')
# ('sanriddha', 'basa')
# ('kshetra', 'basa')
# ('raॉyala', 'taigara')
# ('raॉyala', 'kaita')
# ('taigara', 'kaita')
# ('ekamatra', 'nivasa')
# ('ekamatra', 'sthana')
# ('ekamatra', 'bangala')
# ('nivasa', 'sthana')
# ('nivasa', 'bangala')
# ('nivasa', 'taigara')
# ('sthana', 'bangala')
# ('sthana', 'taigara')
# ('bangala', 'taigara')
# ('dauda़ne', 'vala')
# ('dauda़ne', 'janavara')
# ('vala', 'janavara')('chahate', 'sthanom')
# ('bagha', 'rakshita')
# ('bagha', 'sthanom')
# ('bagha', 'yatra')
# ('rakshita', 'sthanom')
# ('rakshita', 'yatra')
# ('rakshita', 'avashya')
# ('sthanom', 'yatra')
# ('sthanom', 'avashya')
# ('sthanom', 'anandadayaka')
# ('yatra', 'avashya')
# ('yatra', 'anandadayaka')
# ('yatra', 'hogi')
# ('avashya', 'anandadayaka')
# ('avashya', 'hogi')
# ('anandadayaka', 'hogi')
# ('karbeta', 'neshanala')
# ('parka', 'baghom')
# ('parka', 'shikara')
# ('parka', 'ekaashraya')
# ('baghom', 'shikara')
# ('baghom', 'ekaashraya')
# ('baghom', 'sthala')
# ('shikara', 'ekaashraya')
# ('shikara', 'sthala')
# ('shikara', 'jinamem')
# ('ekaashraya', 'sthala')
# ('ekaashraya', 'jinamem')
# ('ekaashraya', 'chara')
# ('sthala', 'jinamem')
# ('sthala', 'chara')
# ('sthala', 'prakara')
# ('jinamem', 'chara')
# ('jinamem', 'prakara')
# ('jinamem', 'hirana')
# ('chara', 'prakara')
# ('chara', 'hirana')
# ('prakara', 'hirana')
# ('jangali', 'suara')
# ('jangali', 'kama')
# ('jangali', 'prasiddha')
# ('suara', 'kama')
# ('suara', 'prasiddha')
# ('suara', 'janavara')
# ('kama', 'prasiddha')
# ('kama', 'janavara')
# ('kama', 'sammilita')
# ('prasiddha', 'janavara')
# ('prasiddha', 'sammilita')
# ('prasiddha', 'svarna')
# ('janavara', 'sammilita')
# ('janavara', 'svarna')
# ('janavara', 'mandira')
# ('sammilita', 'svarna')
# ('sammilita', 'mandira')
# ('sammilita', 'sikkhom')
# ('svarna', 'mandira')
# ('svarna', 'sikkhom')
# ('svarna', 'pavitra')
# ('mandira', 'sikkhom')
# ('mandira', 'pavitra')
# ('mandira', 'nagara')
# ('sikkhom', 'pavitra')
# ('sikkhom', 'nagara')
# ('sikkhom', 'anritasara')
# ('pavitra', 'nagara')
# ('pavitra', 'anritasara')
# ('pavitra', 'sthita')
# ('nagara', 'anritasara')
# ('nagara', 'sthita')
# ('nagara', 'kabhi')
# ('anritasara', 'sthita')
# ('anritasara', 'kabhi')
# ('anritasara', 'ghana')
# ('sthita', 'kabhi')
# ('sthita', 'ghana')
# ('sthita', 'jangala')
# ('kabhi', 'ghana')
# ('kabhi', 'jangala')
# ('kabhi', 'gurunanaka')
# ('ghana', 'jangala')
# ('ghana', 'gurunanaka')
# ('ghana', 'nivasa')
# ('jangala', 'gurunanaka')
# ('jangala', 'nivasa')
# ('jangala', 'sthala')
# ('gurunanaka', 'nivasa')
# ('gurunanaka', 'sthala')
# ('nivasa', 'sthala')
# ('upara', 'sthita')
# ('upara', 'dharmashala')
# ('upara', 'ghane')
# ('sthita', 'dharmashala')
# ('sthita', 'ghane')
# ('sthita', 'chida़')
# ('dharmashala', 'ghane')
# ('dharmashala', 'chida़')
# ('ghane', 'chida़')
# ('peda़om', 'devadara')
# ('peda़om', 'jangalom')
# ('devadara', 'jangalom')
# ('ghiri', 'si')
# ('ghiri', 'jala')
# ('ghiri', 'dharaom')
# ('si', 'jala')
# ('si', 'dharaom')
# ('jala', 'dharaom')
# ('hima', 'rekha')
# ('hima', 'shitala')
# ('hima', 'svastha')
# ('rekha', 'shitala')
# ('rekha', 'svastha')
# ('rekha', 'vatavarana')
# ('shitala', 'svastha')
# ('shitala', 'vatavarana')
# ('shitala', 'parivesha')
# ('svastha', 'vatavarana')
# ('svastha', 'parivesha')
# ('vatavarana', 'parivesha')
# ('lubhavana', 'banata')
# ('kabhi', 'shasana')
# ('mahatvapurna', 'kendra')
# ('mahatvapurna', 'mana')
# ('mahatvapurna', 'jane')
# ('kendra', 'mana')
# ('kendra', 'jane')
# ('kendra', 'vala')
# ('mana', 'jane')
# ('mana', 'vala')
# ('mana', 'chanda')
# ('jane', 'vala')
# ('jane', 'chanda')
# ('jane', 'vansha')
# ('vala', 'chanda')
# ('vala', 'vansha')
# ('chanda', 'vansha')
# ('rajadhani', 'shahara')
# ('kangada़a', 'gaurava')
# ('kangada़a', 'gatha')
# ('kangada़a', 'kahata')
# ('gaurava', 'gatha')
# ('gaurava', 'kahata')
# ('gatha', 'kahata')
# ('itihasa', 'kho')
# ('itihasa', 'ninna')
# ('itihasa', 'himalaya')
# ('kho', 'ninna')
# ('kho', 'himalaya')
# ('kho', 'manorama')
# ('ninna', 'himalaya')
# ('ninna', 'manorama')
# ('ninna', 'ghatiyom')
# ('himalaya', 'manorama')
# ('himalaya', 'ghatiyom')
# ('manorama', 'ghatiyom')
# ('utkrishta', 'dhauladhara')
# ('utkrishta', 'pahadiyom')
# ('utkrishta', 'parirakshita')
# ('dhauladhara', 'pahadiyom')
# ('dhauladhara', 'parirakshita')
# ('dhauladhara', 'ghati')
# ('pahadiyom', 'parirakshita')
# ('pahadiyom', 'ghati')
# ('pahadiyom', 'hari')
# ('parirakshita', 'ghati')
# ('parirakshita', 'hari')
# ('parirakshita', 'bhari')
# ('ghati', 'hari')
# ('ghati', 'bhari')
# ('hari', 'bhari')
# ('parvatiya', 'kshetra')
# ('parvatiya', 'hare')
# ('parvatiya', 'bhare')
# ('kshetra', 'hare')
# ('kshetra', 'bhare')
# ('kshetra', 'pahada़i')
# ('hare', 'bhare')
# ('hare', 'pahada़i')
# ('hare', 'rastom')
# ('bhare', 'pahada़i')
# ('bhare', 'rastom')
# ('bhare', 'stupom')
# ('pahada़i', 'rastom')
# ('pahada़i', 'stupom')
# ('pahada़i', 'mathom')
# ('rastom', 'stupom')
# ('rastom', 'mathom')
# ('rastom', 'mandirom')
# ('stupom', 'mathom')
# ('stupom', 'mandirom')
# ('stupom', 'romancha')
# ('mathom', 'mandirom')
# ('mathom', 'romancha')
# ('mathom', 'prachurata')
# ('mandirom', 'romancha')
# ('mandirom', 'prachurata')
# ('mandirom', 'sanriddha')
# ('romancha', 'prachurata')
# ('romancha', 'sanriddha')
# ('romancha', 'sanskriti')
# ('prachurata', 'sanriddha')
# ('prachurata', 'sanskriti')
# ('prachurata', 'parampara')
# ('sanriddha', 'sanskriti')
# ('sanriddha', 'parampara')
# ('sanriddha', 'parichaya')
# ('sanskriti', 'parampara')
# ('sanskriti', 'parichaya')
# ('sanskriti', 'prapta')
# ('parampara', 'parichaya')
# ('parampara', 'prapta')
# ('parampara', 'kijie')
# ('parichaya', 'prapta')
# ('parichaya', 'kijie')
# ('prapta', 'kijie')
# ('asimita', 'anandaprada')
# ('sanskarom', 'utsavom')
# ('purnatah', 'vilakshana')
# ('sukhadayi', 'yatra')
# ('sukhadayi', 'pradana')
# ('yatra', 'pradana')
# ('–', 'romancha')
# ('–', 'khoja')
# ('romancha', 'khoja')
# ('lambe', 'samaya')
# ('manava', 'hridaya')
# ('bhanti', 'vishala')
# ('bhanti', 'nile')
# ('bhanti', 'akasha')
# ('vishala', 'nile')
# ('vishala', 'akasha')
# ('vishala', 'uda़ne')
# ('nile', 'akasha')
# ('nile', 'uda़ne')
# ('akasha', 'uda़ne')
# ('gahari', 'chaha')
# ('gahari', 'hada')
# ('gahari', 'hama')
# ('chaha', 'hada')
# ('chaha', 'hama')
# ('hada', 'hama')
# ('manava', 'khule')
# ('manava', 'akasha')
# ('manava', 'uda़ne')
# ('khule', 'akasha')
# ('khule', 'uda़ne')
# ('khule', 'havai')
# ('akasha', 'uda़ne')
# ('akasha', 'havai')
# ('akasha', 'khela')
# ('uda़ne', 'havai')
# ('uda़ne', 'khela')
# ('uda़ne', 'romancha')
# ('havai', 'khela')
# ('havai', 'romancha')
# ('havai', 'apanate')
# ('khela', 'romancha')
# ('khela', 'apanate')
# ('khela', 'pyasa')
# ('romancha', 'apanate')
# ('romancha', 'pyasa')
# ('romancha', 'buja')
# ('apanate', 'pyasa')
# ('apanate', 'buja')
# ('apanate', 'pane')
# ('pyasa', 'buja')
# ('pyasa', 'pane')
# ('pyasa', 'sakshama')
# ('buja', 'pane')
# ('buja', 'sakshama')
# ('pane', 'sakshama')
# ('26,000', 'phuta')
# ('26,000', 'unchai')
# ('26,000', 'barpha')
# ('phuta', 'unchai')
# ('phuta', 'barpha')
# ('unchai', 'barpha')
# ('dhaki', 'chotiyom')
# ('shikhara', 'vala')
# ('shikhara', 'himalaya')
# ('shikhara', 'vishva')
# ('vala', 'himalaya')
# ('vala', 'vishva')
# ('himalaya', 'vishva')
# ('sarvashreshtha', 'parvata')
# ('sarvashreshtha', 'shrrinkhala')
# ('sarvashreshtha', 'bharata')
# ('parvata', 'shrrinkhala')
# ('parvata', 'bharata')
# ('shrrinkhala', 'bharata')
# ('paidala', 'yatra')
# ('paidala', 'avismaraniya')
# ('yatra', 'avismaraniya')
# ('anubhava', 'kyom')
# ('anubhava', 'apako')
# ('anubhava', 'prakriti')
# ('kyom', 'apako')
# ('kyom', 'prakriti')
# ('kyom', 'nirmita')
# ('apako', 'prakriti')
# ('apako', 'nirmita')
# ('apako', 'ajnata')
# ('prakriti', 'nirmita')
# ('prakriti', 'ajnata')
# ('prakriti', 'rastom')
# ('nirmita', 'ajnata')
# ('nirmita', 'rastom')
# ('ajnata', 'rastom')
# ('deti,(balki', 'paidala')
# ('deti,(balki', 'yatra')
# ('deti,(balki', 'paryataka')
# ('paidala', 'yatra')
# ('paidala', 'paryataka')
# ('yatra', 'paryataka')
# ('desha', 'logom')
# ('sidhe', 'samparka')
# ('sidhe', 'lati')
# ('sidhe', 'apako')
# ('samparka', 'lati')
# ('samparka', 'apako')
# ('samparka', 'parvatiya')
# ('lati', 'apako')
# ('lati', 'parvatiya')
# ('lati', 'vatavarana')
# ('apako', 'parvatiya')
# ('apako', 'vatavarana')
# ('apako', 'samajane')
# ('parvatiya', 'vatavarana')
# ('parvatiya', 'samajane')
# ('parvatiya', 'sahayata')
# ('vatavarana', 'samajane')
# ('vatavarana', 'sahayata')
# ('samajane', 'sahayata')
# ('himalaya', 'vishva')
# ('himalaya', 'taruna')
# ('himalaya', 'parvata')
# ('vishva', 'taruna')
# ('vishva', 'parvata')
# ('vishva', 'shrrinkhalaom')
# ('taruna', 'parvata')
# ('taruna', 'shrrinkhalaom')
# ('parvata', 'shrrinkhalaom')
# ('vishva', 'sarvashreshtha')
# ('vishva', 'parvatarohana')
# ('sarvashreshtha', 'parvatarohana')
# ('bharatiya', 'himalaya')
# ('bharatiya', 'shrrinkhala')
# ('bharatiya', 'nissandeha')
# ('himalaya', 'shrrinkhala')
# ('himalaya', 'nissandeha')
# ('himalaya', 'vishva')
# ('shrrinkhala', 'nissandeha')
# ('shrrinkhala', 'vishva')
# ('nissandeha', 'vishva')
# ('bhavya', 'prabhavashali')
# ('bhavya', 'parvata')
# ('bhavya', 'shrrinkhalaom')
# ('prabhavashali', 'parvata')
# ('prabhavashali', 'shrrinkhalaom')
# ('parvata', 'shrrinkhalaom')
# ('thara', 'registana')
# ('sahasika', 'yatra')
# ('aisi', 'yatra')
# ('pure', 'jivana')
# ('bhula', 'paryataka')
# ('bhula', 'registani')
# ('bhula', 'anubhava')
# ('paryataka', 'registani')
# ('paryataka', 'anubhava')
# ('paryataka', 'ananda')
# ('registani', 'anubhava')
# ('registani', 'ananda')
# ('registani', 'jaisalamera')
# ('anubhava', 'ananda')
# ('anubhava', 'jaisalamera')
# ('anubhava', 'rajasthana')
# ('ananda', 'jaisalamera')
# ('ananda', 'rajasthana')
# ('jaisalamera', 'rajasthana')
# ('saima', 'sainda')
# ('saima', 'dyunsa')
# ('sainda', 'dyunsa')
# ('le', 'paryatakom')
# ('le', 'manoranjana')
# ('paryatakom', 'manoranjana')
# ('rajasthana', 'paryatana')
# ('rajasthana', 'vibhaga')
# ('paryatana', 'vibhaga')
# ('sayankala', 'sanskritika')
# ('sayankala', 'pradarshanom')
# ('sanskritika', 'pradarshanom')
# ('gira', 'rashtriya')
# ('gira', 'udyana')
# ('gira', 'sagauna')
# ('rashtriya', 'udyana')
# ('rashtriya', 'sagauna')
# ('rashtriya', 'gulamohara')
# ('udyana', 'sagauna')
# ('udyana', 'gulamohara')
# ('udyana', 'khaira')
# ('sagauna', 'gulamohara')
# ('sagauna', 'khaira')
# ('sagauna', 'baragada')
# ('gulamohara', 'khaira')
# ('gulamohara', 'baragada')
# ('gulamohara', 'vrikshom')
# ('khaira', 'baragada')
# ('khaira', 'vrikshom')
# ('baragada', 'vrikshom')
# ('mila', 'jula')
# ('patajada़i', 'vana')
# ('gira', 'rashtriya')
# ('gira', 'udyana')
# ('gira', 'bharata')
# ('rashtriya', 'udyana')
# ('rashtriya', 'bharata')
# ('rashtriya', 'udyana')
# ('udyana', 'bharata')
# ('udyana', 'udyana')
# ('udyana', 'tulana')
# ('bharata', 'udyana')
# ('bharata', 'tulana')
# ('bharata', 'chite')
# ('udyana', 'tulana')
# ('udyana', 'chite')
# ('tulana', 'chite')
# ('adhika', 'abadi')
# ('adhika', 'vala')
# ('adhika', 'avasa')
# ('abadi', 'vala')
# ('abadi', 'avasa')
# ('abadi', 'bharata')
# ('vala', 'avasa')
# ('vala', 'bharata')
# ('vala', 'bagha')
# ('avasa', 'bharata')
# ('avasa', 'bagha')
# ('avasa', 'arakshita')
# ('bharata', 'bagha')
# ('bharata', 'arakshita')
# ('bharata', 'kshetra')
# ('bagha', 'arakshita')
# ('bagha', 'kshetra')
# ('arakshita', 'kshetra')
# ('khunkhara', 'janavara')
# ('surakshita', 'rakha')
# ('surakshita', 'jitani')
# ('surakshita', 'bahutayata')
# ('rakha', 'jitani')
# ('rakha', 'bahutayata')
# ('rakha', 'niyamitata')
# ('jitani', 'bahutayata')
# ('jitani', 'niyamitata')
# ('bahutayata', 'niyamitata')
# ('kanha', 'rashtriya')
# ('kanha', 'udyana')
# ('kanha', 'dekha')
# ('rashtriya', 'udyana')
# ('rashtriya', 'dekha')
# ('udyana', 'dekha')
# ('vaisa', 'kahim')
# ('sarvottama', 'pakshi')
# ('sarvottama', 'udyanom')
# ('pakshi', 'udyanom')
# ('bharatapura', 'pakshi')
# ('bharatapura', 'abhayavana')
# ('bharatapura', 'kevaladeva')
# ('pakshi', 'abhayavana')
# ('pakshi', 'kevaladeva')
# ('pakshi', 'ghana')
# ('abhayavana', 'kevaladeva')
# ('abhayavana', 'ghana')
# ('abhayavana', 'neshanala')
# ('kevaladeva', 'ghana')
# ('kevaladeva', 'neshanala')
# ('kevaladeva', 'parka')
# ('ghana', 'neshanala')
# ('ghana', 'parka')
# ('ghana', 'arakshita')
# ('neshanala', 'parka')
# ('neshanala', 'arakshita')
# ('neshanala', 'kshetra')
# ('parka', 'arakshita')
# ('parka', 'kshetra')
# ('arakshita', 'kshetra')
# ('pashu', 'sanrakshana')
# ('pashu', 'deta')
# ('sanrakshana', 'deta')
# ('udyana', 'dekhane')
# ('udyana', 'adhikansha')
# ('udyana', 'paryatakom')
# ('dekhane', 'adhikansha')
# ('dekhane', 'paryatakom')
# ('adhikansha', 'paryatakom')
# ('mukhya', 'akarshana')
# ('pravasi', 'pakshi')
# ('eshiya', 'sudura')
# ('ate', 'prajanana')
# ('ate', 'sthanom')
# ('ate', 'lautane')
# ('prajanana', 'sthanom')
# ('prajanana', 'lautane')
# ('prajanana', 'thanda')
# ('sthanom', 'lautane')
# ('sthanom', 'thanda')
# ('sthanom', 'bharatapura')
# ('lautane', 'thanda')
# ('lautane', 'bharatapura')
# ('thanda', 'bharatapura')
# ('bharatapura', 'abhayavana')
# ('bharatapura', 'shasakiya')
# ('bharatapura', 'sangrahalaya')
# ('bharatapura', 'mukhya')
# ('shasakiya', 'sangrahalaya')
# ('shasakiya', 'mukhya')
# ('shasakiya', 'dhyana')
# ('sangrahalaya', 'mukhya')
# ('sangrahalaya', 'dhyana')
# ('sangrahalaya', 'khinchane')
# ('mukhya', 'dhyana')
# ('mukhya', 'khinchane')
# ('mukhya', 'valom')
# ('dhyana', 'khinchane')
# ('dhyana', 'valom')
# ('khinchane', 'valom')
# ('bhutakalina', 'rajasi')
# ('bhutakalina', 'vaibhava')
# ('rajasi', 'vaibhava')
# ('sariska', 'udyana')
# ('sariska', 'tendue')
# ('sariska', 'jangali')
# ('udyana', 'tendue')
# ('udyana', 'jangali')
# ('udyana', 'kutte')
# ('tendue', 'jangali')
# ('tendue', 'kutte')
# ('tendue', 'vana')
# ('jangali', 'kutte')
# ('jangali', 'vana')
# ('jangali', 'billi')
# ('kutte', 'vana')
# ('kutte', 'billi')
# ('vana', 'billi')
# ('lakada़bagghe', 'bheda़iye')
# ('lakada़bagghe', 'bagha')
# ('lakada़bagghe', 'mansahari')
# ('bheda़iye', 'bagha')
# ('bheda़iye', 'mansahari')
# ('bheda़iye', 'pashuom')
# ('bagha', 'mansahari')
# ('bagha', 'pashuom')
# ('mansahari', 'pashuom')
# ('sariska', 'risasa')
# ('janasankhya', 'suprasiddha')
# ('janasankhya', 'talavriksha')
# ('janasankhya', 'asa')
# ('suprasiddha', 'talavriksha')
# ('suprasiddha', 'asa')
# ('suprasiddha', 'pasa')
# ('talavriksha', 'asa')
# ('talavriksha', 'pasa')
# ('talavriksha', 'adhika')
# ('asa', 'pasa')
# ('asa', 'adhika')
# ('asa', 'sankhya')
# ('pasa', 'adhika')
# ('pasa', 'sankhya')
# ('adhika', 'sankhya')
# ('jate', 'ranathambhaura')
# ('jate', 'rashtriya')
# ('ranathambhaura', 'rashtriya')
# ('udyana', 'projekta')
# ('udyana', 'taigara')
# ('projekta', 'taigara')
# ('rija़rvsa', 'ऑpha')
# ('rija़rvsa', 'da')
# ('rija़rvsa', 'varlda')
# ('ऑpha', 'da')
# ('ऑpha', 'varlda')
# ('ऑpha', 'vishva')
# ('da', 'varlda')
# ('da', 'vishva')
# ('da', 'bagha')
# ('varlda', 'vishva')
# ('varlda', 'bagha')
# ('varlda', 'sanrakshana')
# ('vishva', 'bagha')
# ('vishva', 'sanrakshana')
# ('vishva', 'pariyojana')
# ('bagha', 'sanrakshana')
# ('bagha', 'pariyojana')
# ('sanrakshana', 'pariyojana')
# ('antargata', 'sammilita')
# ('antargata', 'bagha')
# ('antargata', 'janasankhya')
# ('sammilita', 'bagha')
# ('sammilita', 'janasankhya')
# ('sammilita', 'adhika')
# ('bagha', 'janasankhya')
# ('bagha', 'adhika')
# ('bagha', 'lokapriya')
# ('janasankhya', 'adhika')
# ('janasankhya', 'lokapriya')
# ('adhika', 'lokapriya')
# ('bagha', 'prakritika')
# ('bagha', 'avasa')
# ('bagha', 'dekhana')
# ('prakritika', 'avasa')
# ('prakritika', 'dekhana')
# ('prakritika', 'pratyeka')
# ('avasa', 'dekhana')
# ('avasa', 'pratyeka')
# ('avasa', 'vanyajivana')
# ('dekhana', 'pratyeka')
# ('dekhana', 'vanyajivana')
# ('dekhana', 'samarthaka')
# ('pratyeka', 'vanyajivana')
# ('pratyeka', 'samarthaka')
# ('pratyeka', 'vanchhaniya')
# ('vanyajivana', 'samarthaka')
# ('vanyajivana', 'vanchhaniya')
# ('vanyajivana', 'kalpana')
# ('samarthaka', 'vanchhaniya')
# ('samarthaka', 'kalpana')
# ('samarthaka', 'ranathambhaura')
# ('vanchhaniya', 'kalpana')
# ('vanchhaniya', 'ranathambhaura')
# ('kalpana', 'ranathambhaura')
# ('vana', 'purna')
# ('sakati', 'ranathambhaura')
# ('sakati', 'vanyajivana')
# ('sakati', 'udyana')
# ('ranathambhaura', 'vanyajivana')
# ('ranathambhaura', 'udyana')
# ('ranathambhaura', 'vishva')
# ('vanyajivana', 'udyana')
# ('vanyajivana', 'vishva')
# ('udyana', 'vishva')
# ('darshaniya', 'sthanom')
# ('baghom', 'varchasva')
# ('baghom', 'ranathambhaura')
# ('baghom', 'vanyajivana')
# ('varchasva', 'ranathambhaura')
# ('varchasva', 'vanyajivana')
# ('varchasva', 'udyana')
# ('ranathambhaura', 'vanyajivana')
# ('ranathambhaura', 'udyana')
# ('ranathambhaura', 'daladali')
# ('vanyajivana', 'udyana')
# ('vanyajivana', 'daladali')
# ('vanyajivana', 'magaramachchha')
# ('udyana', 'daladali')
# ('udyana', 'magaramachchha')
# ('udyana', 'ubhayachara')
# ('daladali', 'magaramachchha')
# ('daladali', 'ubhayachara')
# ('daladali', 'pashuom')
# ('magaramachchha', 'ubhayachara')
# ('magaramachchha', 'pashuom')
# ('magaramachchha', 'chida़iyom')
# ('ubhayachara', 'pashuom')
# ('ubhayachara', 'chida़iyom')
# ('pashuom', 'chida़iyom')
# ('272', 'jatiyom')
# ('272', 'sarisripom')
# ('272', 'avasa')
# ('jatiyom', 'sarisripom')
# ('jatiyom', 'avasa')
# ('jatiyom', 'ranathambhaura')
# ('sarisripom', 'avasa')
# ('sarisripom', 'ranathambhaura')
# ('sarisripom', 'vana')
# ('avasa', 'ranathambhaura')
# ('avasa', 'vana')
# ('avasa', 'chhupe')
# ('ranathambhaura', 'vana')
# ('ranathambhaura', 'chhupe')
# ('ranathambhaura', 'khajane')
# ('vana', 'chhupe')
# ('vana', 'khajane')
# ('chhupe', 'khajane')
# ('khoja', 'jipa')
# ('khoja', 'yatra')
# ('khoja', 'upalabdha')
# ('jipa', 'yatra')
# ('jipa', 'upalabdha')
# ('jipa', 'kyonki')
# ('yatra', 'upalabdha')
# ('yatra', 'kyonki')
# ('yatra', 'raॉyala')
# ('upalabdha', 'kyonki')
# ('upalabdha', 'raॉyala')
# ('upalabdha', 'taigara')
# ('kyonki', 'raॉyala')
# ('kyonki', 'taigara')
# ('raॉyala', 'taigara')
# ('sarvottama', 'sadhana')
# ('sarvottama', 'vanyajivana')
# ('sarvottama', 'rashtriya')
# ('sadhana', 'vanyajivana')
# ('sadhana', 'rashtriya')
# ('sadhana', 'udyana')
# ('vanyajivana', 'rashtriya')
# ('vanyajivana', 'udyana')
# ('vanyajivana', 'anya')
# ('rashtriya', 'udyana')
# ('rashtriya', 'anya')
# ('rashtriya', 'akarshana')
# ('udyana', 'anya')
# ('udyana', 'akarshana')
# ('udyana', 'ranathambhaura')
# ('anya', 'akarshana')
# ('anya', 'ranathambhaura')
# ('anya', 'kile')
# ('akarshana', 'ranathambhaura')
# ('akarshana', 'kile')
# ('akarshana', 'khandahara')
# ('ranathambhaura', 'kile')
# ('ranathambhaura', 'khandahara')
# ('ranathambhaura', 'jogi')
# ('kile', 'khandahara')
# ('kile', 'jogi')
# ('kile', 'mahala')
# ('khandahara', 'jogi')
# ('khandahara', 'mahala')
# ('jogi', 'mahala')
# ('10vim', 'shatabdi')
# ('10vim', 'dinankita')
# ('shatabdi', 'dinankita')
# ('aba', 'vana')
# ('aba', 'vishrama')
# ('aba', 'griha')
# ('vana', 'vishrama')
# ('vana', 'griha')
# ('vana', 'parivartita')
# ('vishrama', 'griha')
# ('vishrama', 'parivartita')
# ('vishrama', 'jogi')
# ('griha', 'parivartita')
# ('griha', 'jogi')
# ('griha', 'mahala')
# ('parivartita', 'jogi')
# ('parivartita', 'mahala')
# ('jogi', 'mahala')
# ('bada़e', 'baragada')
# ('taja', 'nissandeha')
# ('taja', 'vishva')
# ('nissandeha', 'vishva')
# ('bhavya', 'bhavanom')
# ('sthapatya', 'bhavyata')
# ('kalatmaka', 'sundarata')
# ('prasiddha', 'taja')
# ('gauravashali', 'rachanaom')
# ('gauravashali', 'gina')
# ('rachanaom', 'gina')
# ('jata', 'vishva')
# ('jata', 'shreshtha')
# ('jata', 'ashcharyom')
# ('vishva', 'shreshtha')
# ('vishva', 'ashcharyom')
# ('shreshtha', 'ashcharyom')
# ('nirapavada', 'rupa')
# ('sammilita', 'bharatiya')
# ('pratishthita', 'kavi')
# ('pratishthita', 'taigora')
# ('pratishthita', 'shashvatata')
# ('kavi', 'taigora')
# ('kavi', 'shashvatata')
# ('kavi', 'chehare')
# ('taigora', 'shashvatata')
# ('taigora', 'chehare')
# ('taigora', 'ansu')
# ('shashvatata', 'chehare')
# ('shashvatata', 'ansu')
# ('chehare', 'ansu')
# ('rupa', 'varnita')
# ('tajamahala', 'nissandeha')
# ('tajamahala', 'mugala')
# ('tajamahala', 'vastukala')
# ('nissandeha', 'mugala')
# ('nissandeha', 'vastukala')
# ('mugala', 'vastukala')
# ('parakashtha', 'nitanta')
# ('parakashtha', 'saralata')
# ('nitanta', 'saralata')
# ('ashcharyajanaka', 'bhavanom')
# ('agara', 'sthapatya')
# ('agara', 'bhavyata')
# ('agara', 'sanriddhi')
# ('sthapatya', 'bhavyata')
# ('sthapatya', 'sanriddhi')
# ('bhavyata', 'sanriddhi')
# ('baja़arom', 'abhushanom')
# ('ati', 'utkrishta')
# ('ati', 'shaharom')
# ('utkrishta', 'shaharom')
# ('taja', 'mahotsava')
# ('samaya', 'shilpagrama')
# ('samaya', 'shahara')
# ('samaya', 'pure')
# ('shilpagrama', 'shahara')
# ('shilpagrama', 'pure')
# ('shilpagrama', 'vishva')
# ('shahara', 'pure')
# ('shahara', 'vishva')
# ('pure', 'vishva')
# ('paryataka', 'ekatra')
# ('bharapura', 'ananda')
# ('bharapura', 'lete')
# ('bharapura', 'agara')
# ('ananda', 'lete')
# ('ananda', 'agara')
# ('ananda', 'ane')
# ('lete', 'agara')
# ('lete', 'ane')
# ('lete', 'paryataka')
# ('agara', 'ane')
# ('agara', 'paryataka')
# ('agara', 'taja')
# ('ane', 'paryataka')
# ('ane', 'taja')
# ('paryataka', 'taja')
# ('banae', 'rakhane')
# ('namuna', 'avashya')
# ('lem', 'agara')
# ('thailom', 'kasidakari')
# ('thailom', 'jutom')
# ('thailom', 'kharidadari')
# ('kasidakari', 'jutom')
# ('kasidakari', 'kharidadari')
# ('kasidakari', 'bada़a')
# ('jutom', 'kharidadari')
# ('jutom', 'bada़a')
# ('jutom', 'akarshana')
# ('kharidadari', 'bada़a')
# ('kharidadari', 'akarshana')
# ('kharidadari', 'petha')
# ('bada़a', 'akarshana')
# ('bada़a', 'petha')
# ('bada़a', 'mithai')
# ('akarshana', 'petha')
# ('akarshana', 'mithai')
# ('akarshana', 'nishchita')
# ('petha', 'mithai')
# ('petha', 'nishchita')
# ('petha', 'rupa')
# ('mithai', 'nishchita')
# ('mithai', 'rupa')
# ('mithai', 'agara')
# ('nishchita', 'rupa')
# ('nishchita', 'agara')
# ('rupa', 'agara')
# ('yadyapi', 'sudura')
# ('sthita', 'khajuraho')
# ('sthita', 'mandira')
# ('sthita', 'sankula')
# ('khajuraho', 'mandira')
# ('khajuraho', 'sankula')
# ('khajuraho', 'sthala')
# ('mandira', 'sankula')
# ('mandira', 'sthala')
# ('mandira', 'videshi')
# ('sankula', 'sthala')
# ('sankula', 'videshi')
# ('sankula', 'bharatiya')
# ('sthala', 'videshi')
# ('sthala', 'bharatiya')
# ('videshi', 'bharatiya')
# ('donom', 'paryatakom')
# ('sarvadhika', 'lokapriya')
# ('sarvadhika', 'sthanom')
# ('lokapriya', 'sthanom')
# ('khajuraho', 'mandira')
# ('murti', 'kala')
# ('paryataka', 'dhyana')
# ('paryataka', 'banae')
# ('paryataka', 'rakhate')
# ('dhyana', 'banae')
# ('dhyana', 'rakhate')
# ('dhyana', 'utkarsha')
# ('banae', 'rakhate')
# ('banae', 'utkarsha')
# ('banae', 'jatila')
# ('rakhate', 'utkarsha')
# ('rakhate', 'jatila')
# ('rakhate', 'aba')
# ('utkarsha', 'jatila')
# ('utkarsha', 'aba')
# ('jatila', 'aba')
# ('hubahu', 'banane')
# ('sakata|', 'nishpadana')
# ('sakata|', 'shreshtha')
# ('sakata|', 'bhavabhivyakti')
# ('nishpadana', 'shreshtha')
# ('nishpadana', 'bhavabhivyakti')
# ('shreshtha', 'bhavabhivyakti')
# ('utkrishta', 'khajuraho')
# ('utkrishta', 'mandira')
# ('utkrishta', 'naritva')
# ('khajuraho', 'mandira')
# ('khajuraho', 'naritva')
# ('mandira', 'naritva')
# ('samarpana', 'kalakara')
# ('srijanatmaka', 'pravrittiyom')
# ('srijanatmaka', 'jivana')
# ('pravrittiyom', 'jivana')
# ('vibhinna', 'pahaluom')
# ('vibhinna', 'bhavom')
# ('pahaluom', 'bhavom')
# ('patthara', 'sundarata')
# (thara, marusthala)              7
# (rashtriya, udyana)              6
# (unta, sapha़ari)                5
# (pailesa, ऑna)                   5
# (raॉyala, taigara)               4
# (saima, dyunsa)                  4
# (pailesa, vhilsa)                4
# (rajasi, yatra)                  4
# (sainda, dyunsa)                 4
# (ऑna, vhilsa)                    4
# (saima, sainda)                  4
# (jana, jata)                     3
# (vanya, jivana)                  3
# (khajuraho, mandira)             3
# (bangala, taigara)               3
# (himalaya, vishva)               3
# (vanyajivana, udyana)            3
# (retile, tile)                   3
# (retile, tilom)                  3
# (parvata, shrrinkhalaom)         2
# (marusthala, sapha़ari)          2
# (tarika, sapha़ari)              2
# (rupa, jata)                     2
# (rajasi, rajasthana)             2
# (gira, udyana)                   2
# (akasha, uda़ne)                 2
# (gira, rashtriya)                2
# (jogi, mahala)                   2
# (sarvottama, paryataka)          2
# (samaya, shahara)                2
#                                 ..
# (dhyana, banae)                  1
# (krishi, baganom)                1
# (vanyajivana, magaramachchha)    1
# (ghana, parka)                   1
# (gahari, chaha)                  1
# (vatavarana, sahayata)           1
# (utpadom, jata)                  1
# (hada, hama)                     1
# (maha, kartika)                  1
# (apako, vatavarana)              1
# (10vim, shatabdi)                1
# (magaramachchha, ubhayachara)    1
# (kile, jogi)                     1
# (kshetrom, hotalom)              1
# (tapamana, milata)               1
# (udayapura, dilli)               1
# (avasa, bharata)                 1
# (shilpakarom, shilpa)            1
# (garama, thandi)                 1
# (anubhava, himalaya)             1
# (nae, nirdeshita)                1
# (karna, shahara)                 1
# (paidala, paryataka)             1
# (yamuna, nadi)                   1
# (yatra, sansara)                 1
# (rupa, varnita)                  1
# (sanriddha, vividha)             1
# (sadhana, udyana)                1
# (paryatakom, prakara)            1
# (chalane, aja)                   1
# Length: 1990, dtype: int64
# rajasthana - 6.564731103736328
# paryataka - 5.096152212715157
# vishva - 4.915333246789211
# udyana - 4.870369471755061
# yatra - 4.061527719505592
# shahara - 3.6508385604678986
# sarvottama - 3.6050943237229087
# sthita - 3.5473565696389393
# bagha - 3.508939155267557
# marusthala - 3.4695960687409717
# jile - 3.3528236439154906
# sapha़ari - 3.2748889052795827
# agara - 3.171012892634582
# romancha - 2.9537906645908603
# sthala - 2.946658242888159
# paryatakom - 2.937465890286088
# ranathambhaura - 2.9197965141840485
# bharata - 2.901455979463883
# jata - 2.821059783779121
# anubhava - 2.812166834120058
# kshetra - 2.730958329630028
# jivana - 2.596469511700528
# sthanom - 2.5904880079117745
# sanskriti - 2.4286060660931335
# bhavya - 2.4183526255443373
# rajasi - 2.3977802647167072
# himalaya - 2.396696564242292
